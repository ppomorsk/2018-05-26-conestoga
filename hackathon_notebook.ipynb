# %% [markdown]
# ## Introduction to Python
#
# Python is the best programming language for prototyping.

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world again")
# Out:
# hello world again

# %%
a=3

# %%
print(a)
# Out:
# 3

# %%
print(a+a)
# Out:
# 6

# %%
type(a)
# Out:
# int

# %%
b=3.3
type(b)
# Out:
# float

# %%
s="hello"

# %%
s+s
# Out:
# 'hellohello'

# %%
string1="hello"

# %%
string2="world"

# %%
string1+string2
# Out:
# 'helloworld'

# %%
type(string1)
# Out:
# str

# %%
dir(a)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'numerator',
#  'real',
#  'to_bytes']

# %%
type(string1)
# Out:
# str

# %%
dir(string1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
string1.capitalize()
# Out:
# 'Hello'

# %%
string1
# Out:
# 'hello'

# %%
help(string1.capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
help(string1.replace)
# Out:
# Help on built-in function replace:
#
# replace(old, new, count=-1, /) method of builtins.str instance
#     Return a copy with all occurrences of substring old replaced by new.
#
#       count
#         Maximum number of occurrences to replace.
#         -1 (the default value) means replace all occurrences.
#
#     If the optional argument count is given, only the first count occurrences are
#     replaced.

# %%
string1="hello hello"
string1.replace("ll","AA", -1)
# Out:
# 'heAAo heAAo'

# %%
dir(string1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(string1.count)
# Out:
# Help on built-in function count:
#
# count(...) method of builtins.str instance
#     S.count(sub[, start[, end]]) -> int
#
#     Return the number of non-overlapping occurrences of substring sub in
#     string S[start:end].  Optional arguments start and end are
#     interpreted as in slice notation.

# %%
string3="Toronto is the capital of Ontario.  It is a nice city"
string3.count("Toronto")
# Out:
# 1

# %%
string3[0:4]
# Out:
# 'Toro'

# %%
string3[:4]
# Out:
# 'Toro'

# %%
string3[4:10]
# Out:
# 'nto is'

# %%
string3[10:]
# Out:
# ' the capital of Ontario.  It is a nice city'

# %%
string3[2]
# Out:
# 'r'

# %%
string3[-1]
# Out:
# 'y'

# %%
string3[-6:]
# Out:
# 'e city'

# %%
string3[0]="t"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-2c718e8468ba> in <module>
# ----> 1 string3[0]="t"
#
# TypeError: 'str' object does not support item assignment

# %%
string3="t"+string3[1:]

# %%
string3
# Out:
# 'toronto is the capital of Ontario.  It is a nice city'

# %% [markdown]
# ## Lists

# %%
mylist = ["A" ,"B" ,"C" ,"D", 1, 2.0, ["1","2"] ]

# %%
mylist
# Out:
# ['A', 'B', 'C', 'D', 1, 2.0, ['1', '2']]

# %%
mylist[0]
# Out:
# 'A'

# %%
mylist[0]="B"

# %%
mylist
# Out:
# ['B', 'B', 'C', 'D', 1, 2.0, ['1', '2']]

# %%
mylist[6]
# Out:
# ['1', '2']

# %%
mylist[6][1]
# Out:
# '2'

# %%
mylist[0:4]
# Out:
# ['B', 'B', 'C', 'D']

# %%
mylist[-1]
# Out:
# ['1', '2']

# %%
for i in [0,1,2,3,4,5]:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in ["a","b","c","d","e"]:
    print(i)
# Out:
# a
# b
# c
# d
# e

# %%
mylist=[]
for i in range(6):
    mylist.append(str(i))
    print(str(i))
# Out:
# 5

# %%
mylist
# Out:
# ['0', '1', '2', '3', '4', '5']

# %%
mylist=[]
for i in range(6):

    if(i==0):
        print("zero")
    elif(i%2==0):
        print(i)
    else:
        print("not even")
# Out:
# zero
# not even
# 2
# not even
# 4
# not even

# %% [markdown]
# ## Working with NLTK
#
# Good resource: https://www.nltk.org/book/

# %%
import nltk

# %%
test_string = "I have a cat, a dog, and a parrot as pets."

# %%
tokens = nltk.word_tokenize(test_string)

# %%
tokens
# Out:
# ['I',
#  'have',
#  'a',
#  'cat',
#  ',',
#  'a',
#  'dog',
#  ',',
#  'and',
#  'a',
#  'parrot',
#  'as',
#  'pets',
#  '.']

# %%
nltk.pos_tag(tokens)
# Out:
# [('I', 'PRP'),
#  ('have', 'VBP'),
#  ('a', 'DT'),
#  ('cat', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('dog', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('parrot', 'NN'),
#  ('as', 'IN'),
#  ('pets', 'NNS'),
#  ('.', '.')]

# %%
test_string="They refuse to permit us to obtain the refuse permit."
tokens = nltk.word_tokenize(test_string)
nltk.pos_tag(tokens)
# Out:
# [('They', 'PRP'),
#  ('refuse', 'VBP'),
#  ('to', 'TO'),
#  ('permit', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('obtain', 'VB'),
#  ('the', 'DT'),
#  ('refuse', 'NN'),
#  ('permit', 'NN'),
#  ('.', '.')]

# %%
test_string="I can drink a can of soda."
tokens = nltk.word_tokenize(test_string)
nltk.pos_tag(tokens)
# Out:
# [('I', 'PRP'),
#  ('can', 'MD'),
#  ('drink', 'VB'),
#  ('a', 'DT'),
#  ('can', 'MD'),
#  ('of', 'IN'),
#  ('soda', 'NN'),
#  ('.', '.')]

# %%
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# LS: list item marker
#     A A. B B. C C. D E F First G H I J K One SP-44001 SP-44002 SP-44005
#     SP-44007 Second Third Three Two * a b c d first five four one six three
#     two
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# PDT: pre-determiner
#     all both half many quite such sure this
# POS: genitive marker
#     ' 's
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# RBS: adverb, superlative
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst
# RP: particle
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
# SYM: symbol
#     % & ' '' ''. ) ). * + ,. < = > @ A[fj] U.S U.S.S.R * ** ***
# TO: "to" as preposition or infinitive marker
#     to
# UH: interjection
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# WDT: WH-determiner
#     that what whatever which whichever
# WP: WH-pronoun
#     that what whatever whatsoever which who whom whosoever
# WP$: WH-pronoun, possessive
#     whose
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# ``: opening quotation mark
#     ` ``

# %%
test_string="I can drink a can of soda."
nltk.pos_tag(nltk.word_tokenize(test_string))
# Out:
# [('I', 'PRP'),
#  ('can', 'MD'),
#  ('drink', 'VB'),
#  ('a', 'DT'),
#  ('can', 'MD'),
#  ('of', 'IN'),
#  ('soda', 'NN'),
#  ('.', '.')]

# %%
nltk.pos_tag(nltk.word_tokenize("I can drink a can of soda."))
# Out:
# [('I', 'PRP'),
#  ('can', 'MD'),
#  ('drink', 'VB'),
#  ('a', 'DT'),
#  ('can', 'MD'),
#  ('of', 'IN'),
#  ('soda', 'NN'),
#  ('.', '.')]

# %%
import pandas as pd

# %%
df = pd.read_csv("elawsCorpus-output.csv",encoding='latin-1')

# %%
df
# Out:
#      Unnamed: 0                                               Text  \
# 0             1  Français Long-Term Care Homes Act, 2007 S.o. 2...
# 1             2  Français Ontario Labour Mobility Act, 2009 S.o...
# 2             3  Français Retirement Homes Act, 2010 S.O. 2010,...
# 3             4  Français Child Care and Early Years Act, 2014 ...
# 4             5  Français Police Record Checks Reform Act, 2015...
# 5             6  Français Cap and Trade Cancellation Act, 2018 ...
# 6             7  Français Business Corporations Act R.S.O. 1990...
# 7             8  Français Liquor Control Act R.S.O. 1990, CHAPT...
# 8             9  Français Liquor Licence Act R.S.O. 1990, CHAPT...
# 9            10  Français Ministry of Revenue Act R.S.O. 1990, ...
# 10           11  Français Gaming Control Act, 1992 S.O. 1992, C...
# 11           12  Français Ontario Lottery and Gaming Corporatio...
# 12           13  Français Licence Appeal Tribunal Act, 1999 S.O...
# 13           14  Français Wine Content and Labelling Act, 2000 ...
# 14           15  Français Horse Racing Licence Act, 2015 S.o. 2...
# 15           16  Français Ontario Cannabis Retail Corporation A...
# 16           17  Français Cannabis Control Act, 2017 S.o. 2017,...
# 17           18  Français Cannabis Licence Act, 2018 S.o. 2018,...
# 18           19  Français Occupational Health and Safety Act R....
# 19           20  Français Crown Employees Collective Bargaining...
# 20           21  Français Public Sector Dispute Resolution Act,...
# 21           22  Français Public Sector Labour Relations Transi...
# 22           23  Français Ontario College of Trades and Apprent...
# 23           24  Français School Boards Collective Bargaining A...
# 24           25  Français Ombudsman Act R.S.O. 1990, Chapter O....
# 25           26  Français Election Act R.S.O. 1990, CHAPTER E.6...
# 26           27  Français Insurance Act R.S.O. 1990, CHAPTER I....
# 27           28  Français Pension Benefits Act R.S.O. 1990, Cha...
# 28           29  Français Legislative Assembly Act R.S.O. 1990,...
# 29           30  Français Financial Administration Act R.S.O. 1...
# ..          ...                                                ...
# 731         732  Français Avian Emblem Act, 1994 S.O. 1994, CHA...
# 732         733  Français Ontario Loan Act, 1994 S.O. 1994, CHA...
# 733         734  Français Donation of Food Act, 1994 S.O. 1994,...
# 734         735  Français Sale of Goods Act R.S.O. 1990, CHAPTE...
# 735         736  Français Statute of Frauds R.S.O. 1990, Chapte...
# 736         737  Français Powers of Attorney Act R.S.O. 1990, C...
# 737         738  Français Ontario Loan Act, 1996 S.O. 1996, CHA...
# 738         739  Français Ontario Loan Act, 1996 (No. 2) S.O. 1...
# 739         740  Français Ontario Institute for Studies in Educ...
# 740         741  Français Geographic Township of Creighton-Davi...
# 741         742  Français United Empire Loyalists Day Act, 199...
# 742         743  Français Ontario Loan Act, 1998 S.O. 1998, CHA...
# 743         744  Français Ontario Agriculture Week Act, 1998 S....
# 744         745  Français Holocaust Memorial Day Act, 1998 S.O....
# 745         746  Français Crown Agency Act R.S.O. 1990, Chapter...
# 746         747  Français Enforcement of Judgments Conventions ...
# 747         748  Français University of Ottawa Heart Institute ...
# 748         749  Français Ontario Association of Former Parliam...
# 749         750  Français German Pioneers Day Act, 2000 S.O. 20...
# 750         751  Français OC Transpo Payments Act, 2000 S.O. 20...
# 751         752  Français Firefighters Memorial Day Act, 2000 ...
# 752         753  Français Toronto Stock Exchange Act R.S.O. 199...
# 753         754  Français Deaf-Blind Awareness Month Act, 2000 ...
# 754         755  Français Town of Moosonee Act, 2000 S.O. 2000,...
# 755         756  Français Imitation Firearms Regulation Act, 20...
# 756         757  Français Good Samaritan Act, 2001 S.O. 2001, C...
# 757         758  Français Electronic Registration Act (Ministry...
# 758         759  Français Horse Riding Safety Act, 2001 S.O. 20...
# 759         760  Français Franco-Ontarian Emblem Act, 2001 S.O....
# 760         761  Français Oak Ridges Moraine Protection Act, 20...
#
#                                       hyperlink
# 0     https://www.ontario.ca/laws/statute/07l08
# 1     https://www.ontario.ca/laws/statute/09o24
# 2     https://www.ontario.ca/laws/statute/10r11
# 3     https://www.ontario.ca/laws/statute/14c11
# 4     https://www.ontario.ca/laws/statute/15p30
# 5     https://www.ontario.ca/laws/statute/18c13
# 6     https://www.ontario.ca/laws/statute/90b16
# 7     https://www.ontario.ca/laws/statute/90l18
# 8     https://www.ontario.ca/laws/statute/90l19
# 9     https://www.ontario.ca/laws/statute/90m33
# 10    https://www.ontario.ca/laws/statute/92g24
# 11    https://www.ontario.ca/laws/statute/99o12
# 12    https://www.ontario.ca/laws/statute/99l12
# 13    https://www.ontario.ca/laws/statute/00w26
# 14    https://www.ontario.ca/laws/statute/15h38
# 15    https://www.ontario.ca/laws/statute/17o26
# 16    https://www.ontario.ca/laws/statute/17c26
# 17    https://www.ontario.ca/laws/statute/18c12
# 18    https://www.ontario.ca/laws/statute/90o01
# 19    https://www.ontario.ca/laws/statute/93c38
# 20   https://www.ontario.ca/laws/statute/97p21a
# 21   https://www.ontario.ca/laws/statute/97p21b
# 22    https://www.ontario.ca/laws/statute/09o22
# 23    https://www.ontario.ca/laws/statute/14s05
# 24    https://www.ontario.ca/laws/statute/90o06
# 25    https://www.ontario.ca/laws/statute/90e06
# 26    https://www.ontario.ca/laws/statute/90i08
# 27    https://www.ontario.ca/laws/statute/90p08
# 28    https://www.ontario.ca/laws/statute/90l10
# 29    https://www.ontario.ca/laws/statute/90f12
# ..                                          ...
# 731   https://www.ontario.ca/laws/statute/94a15
# 732   https://www.ontario.ca/laws/statute/94o16
# 733   https://www.ontario.ca/laws/statute/94d19
# 734   https://www.ontario.ca/laws/statute/90s01
# 735   https://www.ontario.ca/laws/statute/90s19
# 736   https://www.ontario.ca/laws/statute/90p20
# 737   https://www.ontario.ca/laws/statute/96o01
# 738   https://www.ontario.ca/laws/statute/96o18
# 739   https://www.ontario.ca/laws/statute/96o16
# 740   https://www.ontario.ca/laws/statute/97g33
# 741   https://www.ontario.ca/laws/statute/97u42
# 742   https://www.ontario.ca/laws/statute/98o05
# 743   https://www.ontario.ca/laws/statute/98o10
# 744   https://www.ontario.ca/laws/statute/98h25
# 745   https://www.ontario.ca/laws/statute/90c48
# 746   https://www.ontario.ca/laws/statute/99e12
# 747   https://www.ontario.ca/laws/statute/99u16
# 748   https://www.ontario.ca/laws/statute/00o06
# 749   https://www.ontario.ca/laws/statute/00g07
# 750   https://www.ontario.ca/laws/statute/00o19
# 751   https://www.ontario.ca/laws/statute/00f31
# 752   https://www.ontario.ca/laws/statute/90t15
# 753   https://www.ontario.ca/laws/statute/00d34
# 754   https://www.ontario.ca/laws/statute/00t05
# 755   https://www.ontario.ca/laws/statute/00i37
# 756   https://www.ontario.ca/laws/statute/01g02
# 757   https://www.ontario.ca/laws/statute/91e44
# 758   https://www.ontario.ca/laws/statute/01h04
# 759   https://www.ontario.ca/laws/statute/01f05
# 760   https://www.ontario.ca/laws/statute/01o03
#
# [761 rows x 3 columns]

# %%
df.shape
# Out:
# (761, 3)

# %%
df.drop(df.index[20:],inplace=True)

# %%
df.shape
# Out:
# (20, 3)

# %%
cp elawsCorpus-output.csv /tmp/

# %%
print(df.iloc[0,1])
# Out:
# Français Long-Term Care Homes Act, 2007 S.o. 2007, chapter 8 Consolidation Period: From November 1, 2018 to the e-Laws currency date. Last amendment: see Table of Public Statute Provisions Repealed Under Section 10.1 of the Legislation Act, 2006. Legislative History: 2007, c. 8, s. 195 (see Table of Public Statute Provisions Repealed Under Section 10.1 of the Legislation Act, 2006); 2009, c. 33, Sched. 18, s. 15; 2010, c. 11, s. 127; 2010, c. 15, s. 233; 2014, c. 7, Sched. 19; 2015, c. 30, s. 24; 2017, c. 14, Sched. 4, s. 20; CTS 27 AL 10 - 1; 2017, c. 25, Sched. 5, s. 1-53; 2017, c. 25, Sched. 9, s. 101. CONTENTS Preamble PART I FUNDAMENTAL PRINCIPLE AND INTERPRETATION 1. Home: the fundamental principle 2. Interpretation PART II RESIDENTS: RIGHTS, CARE AND SERVICES Residents Bill of Rights 3. Residents Bill of Rights Mission Statement 4. Mission statement Safe and Secure Home 5. Home to be safe, secure environment Plan of Care 6. Plan of care 7. Consent Care and Services 8. Nursing and personal support services 9. Restorative care 10. Recreational and social activities 11. Dietary services and hydration 12. Medical services 13. Information and referral assistance 14. Religious and spiritual practices 15. Accommodation services 16. Volunteer program 17. Staffing and care standards 18. Standards for programs and services Prevention of Abuse and Neglect 19. Duty to protect 20. Policy to promote zero tolerance Reporting and Complaints 21. Complaints procedure  licensee 22. Licensee to forward complaints 23. Licensee must investigate, respond and act 24. Reporting certain matters to Director 25. Inspections or inquiries where information received by Director 26. Whistle-blowing protection 27. Complaint to Ontario Labour Relations Board 28. Obstruction  information to inspectors, Director Minimizing of Restraining 29. Policy to minimize restraining of residents, etc. 30. Protection from certain restraining 30. Protection from restraining and confining 30.1 Confining of resident 31. Restraining by physical devices 33. PASDs that limit or inhibit movement 34. Records on restraining of residents 35. Prohibited devices that limit movement 36. Common law duty Office of the Long-Term Care Homes Resident and Family Adviser 37. Office of the Long-Term Care Homes Resident and Family Adviser Regulations 38. Regulations PART III ADMISSION OF RESIDENTS 39. Application of Part 40. Designation of placement co-ordinators 41. Placement co-ordinator to comply with Act, etc. 42. Requirements for admission to home 43. Eligibility for long-term care home admission 44. Authorization for admission to a home 46. Elements of consent 47. Substitute decision-maker may apply for person 48. Transfer of application 49. Controls on licensee 50. Suspension of admissions where risk of harm 51. Preference for veterans 52. Immunity  placement co-ordinators employees and agents 53. Hearing  ineligibility 54. Appeal to Divisional Court 55. Regulations PART IV COUNCILS Residents Council 56. Residents Council 57. Powers of Residents Council 58. Residents Council assistant Family Council 59. Family Council 60. Powers of Family Council 61. Family Council assistant General 62. Licensee to co-operate with and assist Councils 63. Licensee duty to meet with Council 64. Attendance at meetings  licensees, staff, etc. 65. No interference by licensee 66. Immunity  Council members, assistants 67. Duty of licensee to consult Councils 68. Regulations PART V OPERATION OF HOMES Directors, Officers and Other Staff 69. Duties of directors and officers of a corporation 70. Administrator 71. Director of Nursing and Personal Care 72. Medical Director 73. Staff qualifications 74. Continuity of care  limit on temporary, casual or agency staff 75. Screening measures 76. Training 77. Orientation for volunteers Residents  Information, Agreements, etc. 78. Information for residents, etc. 79. Posting of information 80. Regulated documents for resident 81. Voidable agreements 82. A ...

# %%
text_law=df.iloc[0,1].replace("\x92","'").replace("\x96","-").replace('\x93','"').replace("\x94",'"')

# %%
text_law
# Out:
# 'Français Long-Term Care Homes Act, 2007 S.o. 2007, chapter 8 Consolidation Period: From November 1, 2018 to the e-Laws currency date. Last amendment: see Table of Public Statute Provisions Repealed Under Section 10.1 of the Legislation Act, 2006. Legislative History: 2007, c. 8, s. 195 (see Table of Public Statute Provisions Repealed Under Section 10.1 of the Legislation Act, 2006); 2009, c. 33, Sched. 18, s. 15; 2010, c. 11, s. 127; 2010, c. 15, s. 233; 2014, c. 7, Sched. 19; 2015, c. 30, s. 24; 2017, c. 14, Sched. 4, s. 20; CTS 27 AL 10 - 1; 2017, c. 25, Sched. 5, s. 1-53; 2017, c. 25, Sched. 9, s. 101. CONTENTS Preamble PART I FUNDAMENTAL PRINCIPLE AND INTERPRETATION 1. Home: the fundamental principle 2. Interpretation PART II RESIDENTS: RIGHTS, CARE AND SERVICES Residents\' Bill of Rights 3. Residents\' Bill of Rights Mission Statement 4. Mission statement Safe and Secure Home 5. Home to be safe, secure environment Plan of Care 6. Plan of care 7. Consent Care and Services 8. Nursing and personal support services 9. Restorative care 10. Recreational and social activities 11. Dietary services and hydration 12. Medical services 13. Information and referral assistance 14. Religious and spiritual practices 15. Accommodation services 16. Volunteer program 17. Staffing and care standards 18. Standards for programs and services Prevention of Abuse and Neglect 19. Duty to protect 20. Policy to promote zero tolerance Reporting and Complaints 21. Complaints procedure - licensee 22. Licensee to forward complaints 23. Licensee must investigate, respond and act 24. Reporting certain matters to Director 25. Inspections or inquiries where information received by Director 26. Whistle-blowing protection 27. Complaint to Ontario Labour Relations Board 28. Obstruction - information to inspectors, Director Minimizing of Restraining 29. Policy to minimize restraining of residents, etc. 30. Protection from certain restraining 30. Protection from restraining and confining 30.1 Confining of resident 31. Restraining by physical devices 33. PASDs that limit or inhibit movement 34. Records on restraining of residents 35. Prohibited devices that limit movement 36. Common law duty Office of the Long-Term Care Homes Resident and Family Adviser 37. Office of the Long-Term Care Homes Resident and Family Adviser Regulations 38. Regulations PART III ADMISSION OF RESIDENTS 39. Application of Part 40. Designation of placement co-ordinators 41. Placement co-ordinator to comply with Act, etc. 42. Requirements for admission to home 43. Eligibility for long-term care home admission 44. Authorization for admission to a home 46. Elements of consent 47. Substitute decision-maker may apply for person 48. Transfer of application 49. Controls on licensee 50. Suspension of admissions where risk of harm 51. Preference for veterans 52. Immunity - placement co-ordinator\'s employees and agents 53. Hearing - ineligibility 54. Appeal to Divisional Court 55. Regulations PART IV COUNCILS Residents\' Council 56. Residents\' Council 57. Powers of Residents\' Council 58. Residents\' Council assistant Family Council 59. Family Council 60. Powers of Family Council 61. Family Council assistant General 62. Licensee to co-operate with and assist Councils 63. Licensee duty to meet with Council 64. Attendance at meetings - licensees, staff, etc. 65. No interference by licensee 66. Immunity - Council members, assistants 67. Duty of licensee to consult Councils 68. Regulations PART V OPERATION OF HOMES Directors, Officers and Other Staff 69. Duties of directors and officers of a corporation 70. Administrator 71. Director of Nursing and Personal Care 72. Medical Director 73. Staff qualifications 74. Continuity of care - limit on temporary, casual or agency staff 75. Screening measures 76. Training 77. Orientation for volunteers Residents - Information, Agreements, etc. 78. Information for residents, etc. 79. Posting of information 80. Regulated documents for resident 81. Voidable agreemen ...

# %%
tokens = nltk.word_tokenize(text_law)

# %%
tokens_tagged = nltk.pos_tag(tokens)

# %%
len(tokens_tagged)
# Out:
# 65558

# %%
type(tokens_tagged)
# Out:
# list

# %%
tokens_tagged
# Out:
# [('Français', 'NNP'),
#  ('Long-Term', 'NNP'),
#  ('Care', 'NNP'),
#  ('Homes', 'NNP'),
#  ('Act', 'NNP'),
#  (',', ','),
#  ('2007', 'CD'),
#  ('S.o', 'NNP'),
#  ('.', '.'),
#  ('2007', 'CD'),
#  (',', ','),
#  ('chapter', 'NN'),
#  ('8', 'CD'),
#  ('Consolidation', 'NNP'),
#  ('Period', 'NNP'),
#  (':', ':'),
#  ('From', 'IN'),
#  ('November', 'NNP'),
#  ('1', 'CD'),
#  (',', ','),
#  ('2018', 'CD'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('e-Laws', 'JJ'),
#  ('currency', 'NN'),
#  ('date', 'NN'),
#  ('.', '.'),
#  ('Last', 'JJ'),
#  ('amendment', 'NN'),
#  (':', ':'),
#  ('see', 'NN'),
#  ('Table', 'NN'),
#  ('of', 'IN'),
#  ('Public', 'NNP'),
#  ('Statute', 'NNP'),
#  ('Provisions', 'NNP'),
#  ('Repealed', 'NNP'),
#  ('Under', 'IN'),
#  ('Section', 'NNP'),
#  ('10.1', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Legislation', 'NNP'),
#  ('Act', 'NNP'),
#  (',', ','),
#  ('2006', 'CD'),
#  ('.', '.'),
#  ('Legislative', 'JJ'),
#  ('History', 'NN'),
#  (':', ':'),
#  ('2007', 'CD'),
#  (',', ','),
#  ('c.', 'VBZ'),
#  ('8', 'CD'),
#  (',', ','),
#  ('s.', 'VBD'),
#  ('195', 'CD'),
#  ('(', '('),
#  ('see', 'VB'),
#  ('Table', 'NNP'),
#  ('of', 'IN'),
#  ('Public', 'NNP'),
#  ('Statute', 'NNP'),
#  ('Provisions', 'NNP'),
#  ('Repealed', 'NNP'),
#  ('Under', 'IN'),
#  ('Section', 'NNP'),
#  ('10.1', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Legislation', 'NNP'),
#  ('Act', 'NNP'),
#  (',', ','),
#  ('2006', 'CD'),
#  (')', ')'),
#  (';', ':'),
#  ('2009', 'CD'),
#  (',', ','),
#  ('c.', 'VBZ'),
#  ('33', 'CD'),
#  (',', ','),
#  ('Sched', 'NNP'),
#  ('.', '.'),
#  ('18', 'CD'),
#  (',', ','),
#  ('s.', 'VBD'),
#  ('15', 'CD'),
#  (';', ':'),
#  ('2010', 'CD'),
#  (',', ','),
#  ('c.', 'VBZ'),
#  ('11', 'CD'),
#  (',', ','),
#  ('s.', 'VBD'),
#  ('127', 'CD'),
#  (';', ':'),
#  ('2010', 'CD'),
#  (',', ','),
#  ('c.', 'VBZ'),
#  ('15', 'CD'),
#  (',', ','),
#  ('s.', 'VBD'),
#  ('233', 'CD'),
#  (';', ':'),
#  ('2014', 'CD'),
#  (',', ','),
#  ('c.', 'VBZ'),
#  ('7', 'CD'),
#  (',', ','),
#  ('Sched', 'NNP'),
#  ('.', '.'),
#  ('19', 'CD'),
#  (';', ':'),
#  ('2015', 'CD'),
#  (',', ','),
#  ('c.', 'VBZ'),
#  ('30', 'CD'),
#  (',', ','),
#  ('s.', 'VBD'),
#  ('24', 'CD'),
#  (';', ':'),
#  ('2017', 'CD'),
#  (',', ','),
#  ('c.', 'VBZ'),
#  ('14', 'CD'),
#  (',', ','),
#  ('Sched', 'NNP'),
#  ('.', '.'),
#  ('4', 'CD'),
#  (',', ','),
#  ('s.', 'VBD'),
#  ('20', 'CD'),
#  (';', ':'),
#  ('CTS', 'NNP'),
#  ('27', 'CD'),
#  ('AL', 'NNP'),
#  ('10', 'CD'),
#  ('-', ':'),
#  ('1', 'CD'),
#  (';', ':'),
#  ('2017', 'CD'),
#  (',', ','),
#  ('c.', 'VBZ'),
#  ('25', 'CD'),
#  (',', ','),
#  ('Sched', 'NNP'),
#  ('.', '.'),
#  ('5', 'CD'),
#  (',', ','),
#  ('s.', 'JJ'),
#  ('1-53', 'CD'),
#  (';', ':'),
#  ('2017', 'CD'),
#  (',', ','),
#  ('c.', 'VBZ'),
#  ('25', 'CD'),
#  (',', ','),
#  ('Sched', 'NNP'),
#  ('.', '.'),
#  ('9', 'CD'),
#  (',', ','),
#  ('s.', 'VBD'),
#  ('101', 'CD'),
#  ('.', '.'),
#  ('CONTENTS', 'NNP'),
#  ('Preamble', 'JJ'),
#  ('PART', 'NNP'),
#  ('I', 'PRP'),
#  ('FUNDAMENTAL', 'NNP'),
#  ('PRINCIPLE', 'NNP'),
#  ('AND', 'NNP'),
#  ('INTERPRETATION', 'NNP'),
#  ('1', 'CD'),
#  ('.', '.'),
#  ('Home', 'NN'),
#  (':', ':'),
#  ('the', 'DT'),
#  ('fundamental', 'JJ'),
#  ('principle', 'NN'),
#  ('2', 'CD'),
#  ('.', '.'),
#  ('Interpretation', 'NNP'),
#  ('PART', 'NNP'),
#  ('II', 'NNP'),
#  ('RESIDENTS', 'NNP'),
#  (':', ':'),
#  ('RIGHTS', 'NN'),
#  (',', ','),
#  ('CARE', 'NNP'),
#  ('AND', 'NNP'),
#  ('SERVICES', 'NNP'),
#  ('Residents', 'NNP'),
#  ("'", 'POS'),
#  ('Bill', 'NNP'),
#  ('of', 'IN'),
#  ('Rights', 'NNPS'),
#  ('3', 'CD'),
#  ('.', '.'),
#  ('Residents', 'NNS'),
#  ("'", 'POS'),
#  ('Bill', 'NNP'),
#  ('of', 'IN'),
#  ('Rights', 'NNPS'),
#  ('Mission', 'NNP'),
#  ('Statement', 'NNP'),
#  ('4', 'CD'),
#  ('.', '.'),
#  ('Mission', 'NN'),
#  ('statement', 'NN'),
#  ('Safe', 'NNP'),
#  ('and', 'CC'),
#  ('Secure', 'NNP'),
#  ('Home', 'NNP'),
#  ('5', 'CD'),
#  ('.', '.'),
#  ('Home', 'NN'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('safe', 'JJ'),
#  (',', ','),
#  ('secure', 'JJ'),
#  ('environment', 'NN'),
#  ('Plan', 'NN'),
#  ('of', 'IN'),
#  ('Care', 'NNP'),
#  ('6', 'CD'),
#  ('.', '.'),
#  ('Plan', 'NN'),
#  ('of', 'IN'),
#  ('care', 'NN'),
#  ('7', 'CD'),
#  ('.', '.'),
#  ('Consent', 'NNP'),
#  ('Care', 'NNP'),
#  ('and', 'CC'),
#  ('Services', 'NNPS'),
#  ('8', 'CD'),
#  ('.', '.'),
#  ('Nursing', 'NN'),
#  ('and', 'CC'),
#  ('personal', 'JJ'),
#  ('support', 'NN'),
#  ('services', 'NNS'),
#  ('9', 'CD'),
#  ('.', '.'),
#  ('Restorative', 'NNP'),
#  ('care', 'NN'),
#  ('10', 'CD'),
#  ('.', '.'),
#  ('Recreational', 'JJ'),
#  ('and', 'CC'),
#  ('social', 'JJ'),
#  ('activities', 'NNS'),
#  ('11', 'CD'),
#  ('.', '.'),
#  ('Dietary', 'NNP'),
#  ('services', 'NNS'),
#  ('and', 'CC'),
#  ('hydration', 'NN'),
#  ('12', 'CD'),
#  ('.', '.'),
#  ('Medical', 'NNP'),
#  ('services', 'NNS'),
#  ('13', 'CD'),
#  ('.', '.'),
#  ('Information', 'NN'),
#  ('and', 'CC'),
#  ('referral', 'JJ'),
#  ('assistance', 'NN'),
#  ('14', 'CD'),
#  ('.', '.'),
#  ('Religious', 'JJ'),
#  ('and', 'CC'),
#  ('spiritual', 'JJ'),
#  ('practices', 'NNS'),
#  ('15', 'CD'),
#  ('.', '.'),
#  ('Accommodation', 'NN'),
#  ('services', 'NNS'),
#  ('16', 'CD'),
#  ('.', '.'),
#  ('Volunteer', 'NNP'),
#  ('program', 'NN'),
#  ('17', 'CD'),
#  ('.', '.'),
#  ('Staffing', 'VBG'),
#  ('and', 'CC'),
#  ('care', 'NN'),
#  ('standards', 'NNS'),
#  ('18', 'CD'),
#  ('.', '.'),
#  ('Standards', 'NNS'),
#  ('for', 'IN'),
#  ('programs', 'NNS'),
#  ('and', 'CC'),
#  ('services', 'NNS'),
#  ('Prevention', 'NNP'),
#  ('of', 'IN'),
#  ('Abuse', 'NNP'),
#  ('and', 'CC'),
#  ('Neglect', 'NNP'),
#  ('19', 'CD'),
#  ('.', '.'),
#  ('Duty', 'NN'),
#  ('to', 'TO'),
#  ('protect', 'VB'),
#  ('20', 'CD'),
#  ('.', '.'),
#  ('Policy', 'NN'),
#  ('to', 'TO'),
#  ('promote', 'VB'),
#  ('zero', 'CD'),
#  ('tolerance', 'NN'),
#  ('Reporting', 'NNP'),
#  ('and', 'CC'),
#  ('Complaints', 'NNP'),
#  ('21', 'CD'),
#  ('.', '.'),
#  ('Complaints', 'NNS'),
#  ('procedure', 'JJ'),
#  ('-', ':'),
#  ('licensee', 'NN'),
#  ('22', 'CD'),
#  ('.', '.'),
#  ('Licensee', 'VB'),
#  ('to', 'TO'),
#  ('forward', 'VB'),
#  ('complaints', 'NNS'),
#  ('23', 'CD'),
#  ('.', '.'),
#  ('Licensee', 'NNP'),
#  ('must', 'MD'),
#  ('investigate', 'VB'),
#  (',', ','),
#  ('respond', 'NN'),
#  ('and', 'CC'),
#  ('act', 'NN'),
#  ('24', 'CD'),
#  ('.', '.'),
#  ('Reporting', 'VBG'),
#  ('certain', 'JJ'),
#  ('matters', 'NNS'),
#  ('to', 'TO'),
#  ('Director', 'NNP'),
#  ('25', 'CD'),
#  ('.', '.'),
#  ('Inspections', 'NNS'),
#  ('or', 'CC'),
#  ('inquiries', 'NNS'),
#  ('where', 'WRB'),
#  ('information', 'NN'),
#  ('received', 'VBN'),
#  ('by', 'IN'),
#  ('Director', 'NNP'),
#  ('26', 'CD'),
#  ('.', '.'),
#  ('Whistle-blowing', 'JJ'),
#  ('protection', 'NN'),
#  ('27', 'CD'),
#  ('.', '.'),
#  ('Complaint', 'NN'),
#  ('to', 'TO'),
#  ('Ontario', 'NNP'),
#  ('Labour', 'NNP'),
#  ('Relations', 'NNP'),
#  ('Board', 'NNP'),
#  ('28', 'CD'),
#  ('.', '.'),
#  ('Obstruction', 'NNP'),
#  ('-', ':'),
#  ('information', 'NN'),
#  ('to', 'TO'),
#  ('inspectors', 'NNS'),
#  (',', ','),
#  ('Director', 'NNP'),
#  ('Minimizing', 'NNP'),
#  ('of', 'IN'),
#  ('Restraining', 'VBG'),
#  ('29', 'CD'),
#  ('.', '.'),
#  ('Policy', 'NN'),
#  ('to', 'TO'),
#  ('minimize', 'VB'),
#  ('restraining', 'NN'),
#  ('of', 'IN'),
#  ('residents', 'NNS'),
#  (',', ','),
#  ('etc', 'FW'),
#  ('.', '.'),
#  ('30', 'CD'),
#  ('.', '.'),
#  ('Protection', 'NN'),
#  ('from', 'IN'),
#  ('certain', 'JJ'),
#  ('restraining', 'VBG'),
#  ('30', 'CD'),
#  ('.', '.'),
#  ('Protection', 'NN'),
#  ('from', 'IN'),
#  ('restraining', 'VBG'),
#  ('and', 'CC'),
#  ('confining', 'VBG'),
#  ('30.1', 'CD'),
#  ('Confining', 'NNP'),
#  ('of', 'IN'),
#  ('resident', 'JJ'),
#  ('31', 'CD'),
#  ('.', '.'),
#  ('Restraining', 'VBG'),
#  ('by', 'IN'),
#  ('physical', 'JJ'),
#  ('devices', 'NNS'),
#  ('33', 'CD'),
#  ('.', '.'),
#  ('PASDs', 'VB'),
#  ('that', 'IN'),
#  ('limit', 'NN'),
#  ('or', 'CC'),
#  ('inhibit', 'VB'),
#  ('movement', 'NN'),
#  ('34', 'CD'),
#  ('.', '.'),
#  ('Records', 'NNS'),
#  ('on', 'IN'),
#  ('restraining', 'NN'),
#  ('of', 'IN'),
#  ('residents', 'NNS'),
#  ('35', 'CD'),
#  ('.', '.'),
#  ('Prohibited', 'VBN'),
#  ('devices', 'NNS'),
#  ('that', 'IN'),
#  ('limit', 'VBP'),
#  ('movement', 'NN'),
#  ('36', 'CD'),
#  ('.', '.'),
#  ('Common', 'JJ'),
#  ('law', 'NN'),
#  ('duty', 'NN'),
#  ('Office', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Long-Term', 'NNP'),
#  ('Care', 'NNP'),
#  ('Homes', 'NNP'),
#  ('Resident', 'NNP'),
#  ('and', 'CC'),
#  ('Family', 'NNP'),
#  ('Adviser', 'NNP'),
#  ('37', 'CD'),
#  ('.', '.'),
#  ('Office', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Long-Term', 'NNP'),
#  ('Care', 'NNP'),
#  ('Homes', 'NNP'),
#  ('Resident', 'NNP'),
#  ('and', 'CC'),
#  ('Family', 'NNP'),
#  ('Adviser', 'NNP'),
#  ('Regulations', 'NNP'),
#  ('38', 'CD'),
#  ('.', '.'),
#  ('Regulations', 'NNS'),
#  ('PART', 'NNP'),
#  ('III', 'NNP'),
#  ('ADMISSION', 'NNP'),
#  ('OF', 'NNP'),
#  ('RESIDENTS', 'NNP'),
#  ('39', 'CD'),
#  ('.', '.'),
#  ('Application', 'NN'),
#  ('of', 'IN'),
#  ('Part', 'NNP'),
#  ('40', 'CD'),
#  ('.', '.'),
#  ('Designation', 'NN'),
#  ('of', 'IN'),
#  ('placement', 'JJ'),
#  ('co-ordinators', 'NNS'),
#  ('41', 'CD'),
#  ('.', '.'),
#  ('Placement', 'VB'),
#  ('co-ordinator', 'NN'),
#  ('to', 'TO'),
#  ('comply', 'VB'),
#  ('with', 'IN'),
#  ('Act', 'NNP'),
#  (',', ','),
#  ('etc', 'FW'),
#  ('.', '.'),
#  ('42', 'CD'),
#  ('.', '.'),
#  ('Requirements', 'NNS'),
#  ('for', 'IN'),
#  ('admission', 'NN'),
#  ('to', 'TO'),
#  ('home', 'NN'),
#  ('43', 'CD'),
#  ('.', '.'),
#  ('Eligibility', 'NN'),
#  ('for', 'IN'),
#  ('long-term', 'JJ'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('admission', 'NN'),
#  ('44', 'CD'),
#  ('.', '.'),
#  ('Authorization', 'NN'),
#  ('for', 'IN'),
#  ('admission', 'NN'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('home', 'NN'),
#  ('46', 'CD'),
#  ('.', '.'),
#  ('Elements', 'NNS'),
#  ('of', 'IN'),
#  ('consent', 'NN'),
#  ('47', 'CD'),
#  ('.', '.'),
#  ('Substitute', 'JJ'),
#  ('decision-maker', 'NN'),
#  ('may', 'MD'),
#  ('apply', 'VB'),
#  ('for', 'IN'),
#  ('person', 'NN'),
#  ('48', 'CD'),
#  ('.', '.'),
#  ('Transfer', 'NN'),
#  ('of', 'IN'),
#  ('application', 'NN'),
#  ('49', 'CD'),
#  ('.', '.'),
#  ('Controls', 'NNS'),
#  ('on', 'IN'),
#  ('licensee', 'NN'),
#  ('50', 'CD'),
#  ('.', '.'),
#  ('Suspension', 'NN'),
#  ('of', 'IN'),
#  ('admissions', 'NNS'),
#  ('where', 'WRB'),
#  ('risk', 'NN'),
#  ('of', 'IN'),
#  ('harm', 'NN'),
#  ('51', 'CD'),
#  ('.', '.'),
#  ('Preference', 'NN'),
#  ('for', 'IN'),
#  ('veterans', 'NNS'),
#  ('52', 'CD'),
#  ('.', '.'),
#  ('Immunity', 'NNP'),
#  ('-', ':'),
#  ('placement', 'NN'),
#  ('co-ordinator', 'NN'),
#  ("'s", 'POS'),
#  ('employees', 'NNS'),
#  ('and', 'CC'),
#  ('agents', 'NNS'),
#  ('53', 'CD'),
#  ('.', '.'),
#  ('Hearing', 'VBG'),
#  ('-', ':'),
#  ('ineligibility', 'NN'),
#  ('54', 'CD'),
#  ('.', '.'),
#  ('Appeal', 'NN'),
#  ('to', 'TO'),
#  ('Divisional', 'NNP'),
#  ('Court', 'NNP'),
#  ('55', 'CD'),
#  ('.', '.'),
#  ('Regulations', 'NNS'),
#  ('PART', 'NNP'),
#  ('IV', 'NNP'),
#  ('COUNCILS', 'NNP'),
#  ('Residents', 'NNP'),
#  ("'", 'POS'),
#  ('Council', 'NNP'),
#  ('56', 'CD'),
#  ('.', '.'),
#  ('Residents', 'NNS'),
#  ("'", 'POS'),
#  ('Council', 'NNP'),
#  ('57', 'CD'),
#  ('.', '.'),
#  ('Powers', 'NNS'),
#  ('of', 'IN'),
#  ('Residents', 'NNP'),
#  ("'", 'POS'),
#  ('Council', 'NNP'),
#  ('58', 'CD'),
#  ('.', '.'),
#  ('Residents', 'NNS'),
#  ("'", 'POS'),
#  ('Council', 'NNP'),
#  ('assistant', 'VBP'),
#  ('Family', 'NNP'),
#  ('Council', 'NNP'),
#  ('59', 'CD'),
#  ('.', '.'),
#  ('Family', 'RB'),
#  ('Council', 'NNP'),
#  ('60', 'CD'),
#  ('.', '.'),
#  ('Powers', 'NNS'),
#  ('of', 'IN'),
#  ('Family', 'NNP'),
#  ('Council', 'NNP'),
#  ('61', 'CD'),
#  ('.', '.'),
#  ('Family', 'RB'),
#  ('Council', 'NNP'),
#  ('assistant', 'JJ'),
#  ('General', 'NNP'),
#  ('62', 'CD'),
#  ('.', '.'),
#  ('Licensee', 'VB'),
#  ('to', 'TO'),
#  ('co-operate', 'JJ'),
#  ('with', 'IN'),
#  ('and', 'CC'),
#  ('assist', 'VB'),
#  ('Councils', 'NNP'),
#  ('63', 'CD'),
#  ('.', '.'),
#  ('Licensee', 'NNP'),
#  ('duty', 'NN'),
#  ('to', 'TO'),
#  ('meet', 'VB'),
#  ('with', 'IN'),
#  ('Council', 'NNP'),
#  ('64', 'CD'),
#  ('.', '.'),
#  ('Attendance', 'NN'),
#  ('at', 'IN'),
#  ('meetings', 'NNS'),
#  ('-', ':'),
#  ('licensees', 'NNS'),
#  (',', ','),
#  ('staff', 'NN'),
#  (',', ','),
#  ('etc', 'NN'),
#  ('.', '.'),
#  ('65', 'CD'),
#  ('.', '.'),
#  ('No', 'DT'),
#  ('interference', 'NN'),
#  ('by', 'IN'),
#  ('licensee', 'NN'),
#  ('66', 'CD'),
#  ('.', '.'),
#  ('Immunity', 'NNP'),
#  ('-', ':'),
#  ('Council', 'NN'),
#  ('members', 'NNS'),
#  (',', ','),
#  ('assistants', 'NNS'),
#  ('67', 'CD'),
#  ('.', '.'),
#  ('Duty', 'NN'),
#  ('of', 'IN'),
#  ('licensee', 'NN'),
#  ('to', 'TO'),
#  ('consult', 'VB'),
#  ('Councils', 'NNP'),
#  ('68', 'CD'),
#  ('.', '.'),
#  ('Regulations', 'NNS'),
#  ('PART', 'NNP'),
#  ('V', 'NNP'),
#  ('OPERATION', 'NNP'),
#  ('OF', 'NNP'),
#  ('HOMES', 'NNP'),
#  ('Directors', 'NNP'),
#  (',', ','),
#  ('Officers', 'NNP'),
#  ('and', 'CC'),
#  ('Other', 'JJ'),
#  ('Staff', 'NNP'),
#  ('69', 'CD'),
#  ('.', '.'),
#  ('Duties', 'NNS'),
#  ('of', 'IN'),
#  ('directors', 'NNS'),
#  ('and', 'CC'),
#  ('officers', 'NNS'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('corporation', 'NN'),
#  ('70', 'CD'),
#  ('.', '.'),
#  ('Administrator', 'NN'),
#  ('71', 'CD'),
#  ('.', '.'),
#  ('Director', 'NN'),
#  ('of', 'IN'),
#  ('Nursing', 'NN'),
#  ('and', 'CC'),
#  ('Personal', 'NNP'),
#  ('Care', 'NNP'),
#  ('72', 'CD'),
#  ('.', '.'),
#  ('Medical', 'NNP'),
#  ('Director', 'NNP'),
#  ('73', 'CD'),
#  ('.', '.'),
#  ('Staff', 'NNP'),
#  ('qualifications', 'VBZ'),
#  ('74', 'CD'),
#  ('.', '.'),
#  ('Continuity', 'NN'),
#  ('of', 'IN'),
#  ('care', 'NN'),
#  ('-', ':'),
#  ('limit', 'NN'),
#  ('on', 'IN'),
#  ('temporary', 'JJ'),
#  (',', ','),
#  ('casual', 'JJ'),
#  ('or', 'CC'),
#  ('agency', 'NN'),
#  ('staff', 'NN'),
#  ('75', 'CD'),
#  ('.', '.'),
#  ('Screening', 'VBG'),
#  ('measures', 'NNS'),
#  ('76', 'CD'),
#  ('.', '.'),
#  ('Training', 'VBG'),
#  ('77', 'CD'),
#  ('.', '.'),
#  ('Orientation', 'NN'),
#  ('for', 'IN'),
#  ('volunteers', 'NNS'),
#  ('Residents', 'NNP'),
#  ('-', ':'),
#  ('Information', 'NN'),
#  (',', ','),
#  ('Agreements', 'NNP'),
#  (',', ','),
#  ('etc', 'FW'),
#  ('.', '.'),
#  ('78', 'CD'),
#  ('.', '.'),
#  ('Information', 'NN'),
#  ('for', 'IN'),
#  ('residents', 'NNS'),
#  (',', ','),
#  ('etc', 'FW'),
#  ('.', '.'),
#  ('79', 'CD'),
#  ('.', '.'),
#  ('Posting', 'VBG'),
#  ('of', 'IN'),
#  ('information', 'NN'),
#  ('80', 'CD'),
#  ('.', '.'),
#  ('Regulated', 'VBN'),
#  ('documents', 'NNS'),
#  ('for', 'IN'),
#  ('resident', 'JJ'),
#  ('81', 'CD'),
#  ('.', '.'),
#  ('Voidable', 'JJ'),
#  ('agreements', 'NNS'),
#  ('82', 'CD'),
#  ('.', '.'),
#  ('Agreement', 'NN'),
#  ('can', 'MD'),
#  ('not', 'RB'),
#  ('prevent', 'VB'),
#  ('withdrawal', 'NN'),
#  ('of', 'IN'),
#  ('consent', 'NN'),
#  (',', ','),
#  ('etc', 'FW'),
#  ('.', '.'),
#  ('83', 'CD'),
#  ('.', '.'),
#  ('Coercion', 'NN'),
#  ('prohibited', 'VBD'),
#  ('General', 'NNP'),
#  ('Management', 'NNP'),
#  ('84', 'CD'),
#  ('.', '.'),
#  ('Continuous', 'JJ'),
#  ('quality', 'NN'),
#  ('improvement', 'NN'),
#  ('85', 'CD'),
#  ('.', '.'),
#  ('Satisfaction', 'NNP'),
#  ('survey', 'NN'),
#  ('86', 'CD'),
#  ('.', '.'),
#  ('Infection', 'NN'),
#  ('prevention', 'NN'),
#  ('and', 'CC'),
#  ('control', 'NN'),
#  ('program', 'NN'),
#  ('87', 'CD'),
#  ('.', '.'),
#  ('Emergency', 'NN'),
#  ('plans', 'VBZ'),
#  ('88', 'CD'),
#  ('.', '.'),
#  ('Reports', 'NNS'),
#  ('Regulations', 'NNPS'),
#  ('89', 'CD'),
#  ('.', '.'),
#  ('Regulations', 'NNS'),
#  ('PART', 'NNP'),
#  ('VI', 'NNP'),
#  ('FUNDING', 'NNP'),
#  ('90', 'CD'),
#  ('.', '.'),
#  ('Funding', 'VBG'),
#  ('91', 'CD'),
#  ('.', '.'),
#  ('Resident', 'NN'),
#  ('charges', 'NNS'),
#  ('92', 'CD'),
#  ('.', '.'),
#  ('Accounts', 'NNS'),
#  ('and', 'CC'),
#  ('records', 'NNS'),
#  ('93', 'CD'),
#  ('.', '.'),
#  ('Non-arm', 'NN'),
#  ("'s", 'POS'),
#  ('length', 'NN'),
#  ('transactions', 'NNS'),
#  (',', ','),
#  ('limitation', 'NN'),
#  ('94', 'CD'),
#  ('.', '.'),
#  ('Regulations', 'NNS'),
#  ('PART', 'NNP'),
#  ('VII', 'NNP'),
#  ('LICENSING', 'NNP'),
#  ('95', 'CD'),
#  ('.', '.'),
#  ('Licence', 'NN'),
#  ('required', 'VBD'),
#  ('96', 'CD'),
#  ('.', '.'),
#  ('Public', 'JJ'),
#  ('interest', 'NN'),
#  ('-', ':'),
#  ('need', 'NN'),
#  ('97', 'CD'),
#  ('.', '.'),
#  ('Public', 'JJ'),
#  ('interest', 'NN'),
#  ('-', ':'),
#  ('who', 'WP'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('issued', 'VBN'),
#  ('a', 'DT'),
#  ('licence', 'NN'),
#  ('98', 'CD'),
#  ('.', '.'),
#  ('Limitations', 'NNS'),
#  ('on', 'IN'),
#  ('eligibility', 'NN'),
#  ('for', 'IN'),
#  ('licence', 'NN'),
#  ('99', 'CD'),
#  ('.', '.'),
#  ('Issue', 'NN'),
#  ('of', 'IN'),
#  ('licence', 'NN'),
#  ('100', 'CD'),
#  ('.', '.'),
#  ('Undertaking', 'VBG'),
#  ('to', 'TO'),
#  ('issue', 'VB'),
#  ('licence', 'NN'),
#  ('101', 'CD'),
#  ('.', '.'),
#  ('Conditions', 'NNS'),
#  ('of', 'IN'),
#  ('licence', 'NN'),
#  ('102', 'CD'),
#  ('.', '.'),
#  ('Term', 'CD'),
#  ('of', 'IN'),
#  ('licence', 'NN'),
#  ('103', 'CD'),
#  ('.', '.'),
#  ('Notice', 'NN'),
#  ('at', 'IN'),
#  ('end', 'NN'),
#  ('of', 'IN'),
#  ('term', 'NN'),
#  ('104', 'CD'),
#  ('.', '.'),
#  ('Beds', 'NNS'),
#  ('allowed', 'VBN'),
#  ('under', 'IN'),
#  ('licence', 'NN'),
#  ('105', 'CD'),
#  ('.', '.'),
#  ('Transfers', 'NNS'),
#  (',', ','),
#  ('limitation', 'NN'),
#  ('106', 'CD'),
#  ('.', '.'),
#  ('Public', 'JJ'),
#  ('consultation', 'NN'),
#  ('107', 'CD'),
#  ('.', '.'),
#  ('Exercise', 'NN'),
#  ('of', 'IN'),
#  ('security', 'NN'),
#  ('interests', 'NNS'),
#  ('108', 'CD'),
#  ('.', '.'),
#  ('Notice', 'NNP'),
#  ('109', 'CD'),
#  ('.', '.'),
#  ('Gaining', 'VBG'),
#  ('controlling', 'VBG'),
#  ('interest', 'NN'),
#  ('110', 'CD'),
#  ('.', '.'),
#  ('Management', 'NN'),
#  ('contracts', 'NNS'),
#  ('111', 'CD'),
#  ('.', '.'),
#  ('Temporary', 'JJ'),
#  ('licences', 'NNS'),
#  ('112', 'CD'),
#  ('.', '.'),
#  ('Temporary', 'JJ'),
#  ('emergency', 'NN'),
#  ('licences', 'VBZ'),
#  ('113', 'CD'),
#  ('.', '.'),
#  ('Short', 'JJ'),
#  ('term', 'NN'),
#  ('authorizations', 'NNS'),
#  ('114', 'CD'),
#  ('.', '.'),
#  ('Amendments', 'NNS'),
#  ('with', 'IN'),
#  ('consent', 'NN'),
#  ('115', 'CD'),
#  ('.', '.'),
#  ('Competitive', 'JJ'),
#  ('process', 'NN'),
#  ('116', 'CD'),
#  ('.', '.'),
#  ('No', 'DT'),
#  ('appeal', 'NN'),
#  ('117', 'CD'),
#  ('.', '.'),
#  ('Regulations', 'NNS'),
#  ('PART', 'NNP'),
#  ('VIII', 'NNP'),
#  ('MUNICIPAL', 'NNP'),
#  ('HOMES', 'NNP'),
#  ('AND', 'NNP'),
#  ('FIRST', 'NNP'),
#  ('NATIONS', 'NNP'),
#  ('HOMES', 'NNP'),
#  ('Interpretation', 'NNP'),
#  ('118', 'CD'),
#  ('.', '.'),
#  ('Interpretation', 'NN'),
#  ('Southern', 'NNP'),
#  ('Homes', 'NNP'),
#  ('119', 'CD'),
#  ('.', '.'),
#  ('Southern', 'JJ'),
#  ('municipal', 'JJ'),
#  ('homes', 'NNS'),
#  ('120', 'CD'),
#  ('.', '.'),
#  ('Joint', 'JJ'),
#  ('homes', 'NNS'),
#  ('-', ':'),
#  ('south', 'RB'),
#  ('121', 'CD'),
#  ('.', '.'),
#  ('Agreement', 'NN'),
#  ('to', 'TO'),
#  ('help', 'VB'),
#  ('maintain', 'VB'),
#  ('home', 'NN'),
#  ('-', ':'),
#  ('south', 'JJ'),
#  ('Northern', 'NNP'),
#  ('Homes', 'NNP'),
#  ('122', 'CD'),
#  ('.', '.'),
#  ...]

# %%
list(filter(  lambda x: x[1]=="NN", tokens_tagged))
# Out:
# [('chapter', 'NN'),
#  ('currency', 'NN'),
#  ('date', 'NN'),
#  ('amendment', 'NN'),
#  ('see', 'NN'),
#  ('Table', 'NN'),
#  ('History', 'NN'),
#  ('Home', 'NN'),
#  ('principle', 'NN'),
#  ('RIGHTS', 'NN'),
#  ('Mission', 'NN'),
#  ('statement', 'NN'),
#  ('Home', 'NN'),
#  ('environment', 'NN'),
#  ('Plan', 'NN'),
#  ('Plan', 'NN'),
#  ('care', 'NN'),
#  ('Nursing', 'NN'),
#  ('support', 'NN'),
#  ('care', 'NN'),
#  ('hydration', 'NN'),
#  ('Information', 'NN'),
#  ('assistance', 'NN'),
#  ('Accommodation', 'NN'),
#  ('program', 'NN'),
#  ('care', 'NN'),
#  ('Duty', 'NN'),
#  ('Policy', 'NN'),
#  ('tolerance', 'NN'),
#  ('licensee', 'NN'),
#  ('respond', 'NN'),
#  ('act', 'NN'),
#  ('information', 'NN'),
#  ('protection', 'NN'),
#  ('Complaint', 'NN'),
#  ('information', 'NN'),
#  ('Policy', 'NN'),
#  ('restraining', 'NN'),
#  ('Protection', 'NN'),
#  ('Protection', 'NN'),
#  ('limit', 'NN'),
#  ('movement', 'NN'),
#  ('restraining', 'NN'),
#  ('movement', 'NN'),
#  ('law', 'NN'),
#  ('duty', 'NN'),
#  ('Office', 'NN'),
#  ('Application', 'NN'),
#  ('Designation', 'NN'),
#  ('co-ordinator', 'NN'),
#  ('admission', 'NN'),
#  ('home', 'NN'),
#  ('Eligibility', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('admission', 'NN'),
#  ('Authorization', 'NN'),
#  ('admission', 'NN'),
#  ('home', 'NN'),
#  ('consent', 'NN'),
#  ('decision-maker', 'NN'),
#  ('person', 'NN'),
#  ('Transfer', 'NN'),
#  ('application', 'NN'),
#  ('licensee', 'NN'),
#  ('Suspension', 'NN'),
#  ('risk', 'NN'),
#  ('harm', 'NN'),
#  ('Preference', 'NN'),
#  ('placement', 'NN'),
#  ('co-ordinator', 'NN'),
#  ('ineligibility', 'NN'),
#  ('Appeal', 'NN'),
#  ('duty', 'NN'),
#  ('Attendance', 'NN'),
#  ('staff', 'NN'),
#  ('etc', 'NN'),
#  ('interference', 'NN'),
#  ('licensee', 'NN'),
#  ('Council', 'NN'),
#  ('Duty', 'NN'),
#  ('licensee', 'NN'),
#  ('corporation', 'NN'),
#  ('Administrator', 'NN'),
#  ('Director', 'NN'),
#  ('Nursing', 'NN'),
#  ('Continuity', 'NN'),
#  ('care', 'NN'),
#  ('limit', 'NN'),
#  ('agency', 'NN'),
#  ('staff', 'NN'),
#  ('Orientation', 'NN'),
#  ('Information', 'NN'),
#  ('Information', 'NN'),
#  ('information', 'NN'),
#  ('Agreement', 'NN'),
#  ('withdrawal', 'NN'),
#  ('consent', 'NN'),
#  ('Coercion', 'NN'),
#  ('quality', 'NN'),
#  ('improvement', 'NN'),
#  ('survey', 'NN'),
#  ('Infection', 'NN'),
#  ('prevention', 'NN'),
#  ('control', 'NN'),
#  ('program', 'NN'),
#  ('Emergency', 'NN'),
#  ('Resident', 'NN'),
#  ('Non-arm', 'NN'),
#  ('length', 'NN'),
#  ('limitation', 'NN'),
#  ('Licence', 'NN'),
#  ('interest', 'NN'),
#  ('need', 'NN'),
#  ('interest', 'NN'),
#  ('licence', 'NN'),
#  ('eligibility', 'NN'),
#  ('licence', 'NN'),
#  ('Issue', 'NN'),
#  ('licence', 'NN'),
#  ('licence', 'NN'),
#  ('licence', 'NN'),
#  ('licence', 'NN'),
#  ('Notice', 'NN'),
#  ('end', 'NN'),
#  ('term', 'NN'),
#  ('licence', 'NN'),
#  ('limitation', 'NN'),
#  ('consultation', 'NN'),
#  ('Exercise', 'NN'),
#  ('security', 'NN'),
#  ('interest', 'NN'),
#  ('Management', 'NN'),
#  ('emergency', 'NN'),
#  ('term', 'NN'),
#  ('consent', 'NN'),
#  ('process', 'NN'),
#  ('appeal', 'NN'),
#  ('Interpretation', 'NN'),
#  ('Agreement', 'NN'),
#  ('home', 'NN'),
#  ('Agreement', 'NN'),
#  ('home', 'NN'),
#  ('district', 'NN'),
#  ('home', 'NN'),
#  ('board', 'NN'),
#  ('management', 'NN'),
#  ('Operating', 'NN'),
#  ('apportionment', 'NN'),
#  ('board', 'NN'),
#  ('management', 'NN'),
#  ('Capital', 'NN'),
#  ('apportionment', 'NN'),
#  ('board', 'NN'),
#  ('management', 'NN'),
#  ('management', 'NN'),
#  ('Approval', 'NN'),
#  ('Application', 'NN'),
#  ('management', 'NN'),
#  ('appointment', 'NN'),
#  ('information', 'NN'),
#  ('disclosure', 'NN'),
#  ('Director', 'NN'),
#  ('Director', 'NN'),
#  ('control', 'NN'),
#  ('consent', 'NN'),
#  ('control', 'NN'),
#  ('exercise', 'NN'),
#  ('power', 'NN'),
#  ('control', 'NN'),
#  ('Appointment', 'NN'),
#  ('inspection', 'NN'),
#  ('inspection', 'NN'),
#  ('entry', 'NN'),
#  ('inspection', 'NN'),
#  ('report', 'NN'),
#  ('Obstruction', 'NN'),
#  ('Enforcement', 'NN'),
#  ('inspector', 'NN'),
#  ('Compliance', 'NN'),
#  ('Work', 'NN'),
#  ('activity', 'NN'),
#  ('Order', 'NN'),
#  ('funding', 'NN'),
#  ('management', 'NN'),
#  ('penalty', 'NN'),
#  ('Revocation', 'NN'),
#  ('manager', 'NN'),
#  ('suspension', 'NN'),
#  ('diligence', 'NN'),
#  ('order', 'NN'),
#  ('notice', 'NN'),
#  ('Order', 'NN'),
#  ('notice', 'NN'),
#  ('bar', 'NN'),
#  ('conviction', 'NN'),
#  ('service', 'NN'),
#  ('court', 'NN'),
#  ('inspector', 'NN'),
#  ('order', 'NN'),
#  ('notice', 'NN'),
#  ('Appeal', 'NN'),
#  ('order', 'NN'),
#  ('notice', 'NN'),
#  ('decision', 'NN'),
#  ('appeal', 'NN'),
#  ('stay', 'NN'),
#  ('order', 'NN'),
#  ('decision', 'NN'),
#  ('Decision', 'NN'),
#  ('court', 'NN'),
#  ('Recognition', 'NN'),
#  ('evidence', 'NN'),
#  ('appointment', 'NN'),
#  ('information', 'NN'),
#  ('collection', 'NN'),
#  ('Restriction', 'NN'),
#  ('Immunity', 'NN'),
#  ('consultation', 'NN'),
#  ('Transition', 'NN'),
#  ('mission', 'NN'),
#  ('statement', 'NN'),
#  ('Transition', 'NN'),
#  ('cause', 'NN'),
#  ('action', 'NN'),
#  ('enactment', 'NN'),
#  ('term', 'NN'),
#  ('extension', 'NN'),
#  ('Government', 'NN'),
#  ('care', 'NN'),
#  ('health', 'NN'),
#  ('well-being', 'NN'),
#  ('care', 'NN'),
#  ('future', 'NN'),
#  ('collaboration', 'NN'),
#  ('respect', 'NN'),
#  ('amongst', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('service', 'NN'),
#  ('community', 'NN'),
#  ('care', 'NN'),
#  ('resident', 'NN'),
#  ('safety', 'NN'),
#  ('principle', 'NN'),
#  ('access', 'NN'),
#  ('care', 'NN'),
#  ('need', 'NN'),
#  ('accountability', 'NN'),
#  ('transparency', 'NN'),
#  ('care', 'NN'),
#  ('way', 'NN'),
#  ('interest', 'NN'),
#  ('public', 'NN'),
#  ('delivery', 'NN'),
#  ('high-quality', 'NN'),
#  ('care', 'NN'),
#  ('compliance', 'NN'),
#  ('inspection', 'NN'),
#  ('enforcement', 'NN'),
#  ('system', 'NN'),
#  ('responsibility', 'NN'),
#  ('action', 'NN'),
#  ('care', 'NN'),
#  ('safety', 'NN'),
#  ('security', 'NN'),
#  ('commitment', 'NN'),
#  ('quality', 'NN'),
#  ('accommodation', 'NN'),
#  ('environment', 'NN'),
#  ('quality', 'NN'),
#  ('life', 'NN'),
#  ('care', 'NN'),
#  ('care', 'NN'),
#  ('diversity', 'NN'),
#  ('community', 'NN'),
#  ('importance', 'NN'),
#  ('delivery', 'NN'),
#  ('care', 'NN'),
#  ('environment', 'NN'),
#  ('quality', 'NN'),
#  ('improvement', 'NN'),
#  ('promotion', 'NN'),
#  ('delivery', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('advice', 'NN'),
#  ('consent', 'NN'),
#  ('part', 'NN'),
#  ('principLe', 'NN'),
#  ('interpretation', 'NN'),
#  ('Home', 'NN'),
#  ('principle', 'NN'),
#  ('principle', 'NN'),
#  ('interpretation', 'NN'),
#  ('anything', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('home', 'NN'),
#  ('place', 'NN'),
#  ('dignity', 'NN'),
#  ('security', 'NN'),
#  ('safety', 'NN'),
#  ('comfort', 'NN'),
#  ('Interpretation', 'NN'),
#  ('abuse', 'NN'),
#  ('relation', 'NN'),
#  ('resident', 'NN'),
#  ('abuse', 'NN'),
#  ('case', 'NN'),
#  ('traitement', 'NN'),
#  ('relation', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('home', 'NN'),
#  ('section', 'NN'),
#  ('administrateur', 'NN'),
#  ('du', 'NN'),
#  ('foyer', 'NN'),
#  ("d'appel", 'NN'),
#  ('care', 'NN'),
#  ('treatment', 'NN'),
#  ('Note', 'NN'),
#  ('day', 'NN'),
#  ('proclamation', 'NN'),
#  ('subsection', 'NN'),
#  ('definition', 'NN'),
#  ('confine', 'NN'),
#  ('respect', 'NN'),
#  ('law', 'NN'),
#  ('duty', 'NN'),
#  ('caregiver', 'NN'),
#  ('person', 'NN'),
#  ('section', 'NN'),
#  ('meaning', 'NN'),
#  ('confiner', 'NN'),
#  ('person', 'NN'),
#  ('section', 'NN'),
#  ('person', 'NN'),
#  ('person', 'NN'),
#  ('provision', 'NN'),
#  ('term', 'NN'),
#  ('directeur', 'NN'),
#  ('relation', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('home', 'NN'),
#  ('section', 'NN'),
#  ('directeur', 'NN'),
#  ('equity', 'NN'),
#  ('share', 'NN'),
#  ('share', 'NN'),
#  ('class', 'NN'),
#  ('corporation', 'NN'),
#  ('voting', 'NN'),
#  ('right', 'NN'),
#  ('action', 'NN'),
#  ('participante', 'NN'),
#  ('principle', 'NN'),
#  ('principle', 'NN'),
#  ('section', 'NN'),
#  ('principe', 'NN'),
#  ('information', 'NN'),
#  ('decision', 'NN'),
#  ('matter', 'NN'),
#  ('reasonably', 'NN'),
#  ('decision', 'NN'),
#  ('lack', 'NN'),
#  ('decision', 'NN'),
#  ('intervention', 'NN'),
#  ('action', 'NN'),
#  ('procedure', 'NN'),
#  ('activity', 'NN'),
#  ('outcome', 'NN'),
#  ('condition', 'NN'),
#  ('diagnosis', 'NN'),
#  ('intervention', 'NN'),
#  ('licensee', 'NN'),
#  ('holder', 'NN'),
#  ('licence', 'NN'),
#  ('municipality', 'NN'),
#  ('board', 'NN'),
#  ('management', 'NN'),
#  ('home', 'NN'),
#  ('home', 'NN'),
#  ('home', 'NN'),
#  ('titulaire', 'NN'),
#  ('health', 'NN'),
#  ('integration', 'NN'),
#  ('network', 'NN'),
#  ('health', 'NN'),
#  ('integration', 'NN'),
#  ('network', 'NN'),
#  ('section', 'NN'),
#  ("d'intégration", 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('place', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('home', 'NN'),
#  ('home', 'NN'),
#  ('home', 'NN'),
#  ('foyer', 'NN'),
#  ('durée', 'NN'),
#  ('responsibility', 'NN'),
#  ('administration', 'NN'),
#  ('ministère', 'NN'),
#  ('member', 'NN'),
#  ('médecin', 'NN'),
#  ('nurse', 'NN'),
#  ('member', 'NN'),
#  ('certificate', 'NN'),
#  ('registration', 'NN'),
#  ('nurse', 'NN'),
#  ('autorisée', 'NN'),
#  ('autorisé', 'NN'),
#  ('nurse', 'NN'),
#  ('class', 'NN'),
#  ('nurse', 'NN'),
#  ('certificate', 'NN'),
#  ('registration', 'NN'),
#  ('ou', 'NN'),
#  ('infirmier', 'NN'),
#  ('supérieure', 'NN'),
#  ('nurse', 'NN'),
#  ('member', 'NN'),
#  ('certificate', 'NN'),
#  ('registration', 'NN'),
#  ('nurse', 'NN'),
#  ('auxiliaire', 'NN'),
#  ('autorisée', 'NN'),
#  ('auxiliaire', 'NN'),
#  ('autorisé', 'NN'),
#  ('requirement', 'NN'),
#  ('order', 'NN'),
#  ('agreement', 'NN'),
#  ('condition', 'NN'),
#  ('licence', 'NN'),
#  ('approval', 'NN'),
#  ('condition', 'NN'),
#  ('funding', 'NN'),
#  ('section', 'NN'),
#  ('subsection', 'NN'),
#  ('policy', 'NN'),
#  ('section', 'NN'),
#  ('exigence', 'NN'),
#  ('que', 'NN'),
#  ('prévoit', 'NN'),
#  ('la', 'NN'),
#  ('resident', 'NN'),
#  ('person', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('résident', 'NN'),
#  ('list', 'NN'),
#  ('section', 'NN'),
#  ('déclaration', 'NN'),
#  ('adviser', 'NN'),
#  ('person', 'NN'),
#  ('accordance', 'NN'),
#  ('adviser', 'NN'),
#  ('conseiller', 'NN'),
#  ('matière', 'NN'),
#  ('unit', 'NN'),
#  ('area', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('secure', 'NN'),
#  ('unit', 'NN'),
#  ('accordance', 'NN'),
#  ('Note', 'NN'),
#  ('day', 'NN'),
#  ('proclamation', 'NN'),
#  ('definition', 'NN'),
#  ('unit', 'NN'),
#  ('subsection', 'NN'),
#  ('spouse', 'NN'),
#  ('spouse', 'NN'),
#  ('section', 'NN'),
#  ('b', 'NN'),
#  ('conjugal', 'NN'),
#  ('relationship', 'NN'),
#  ('marriage', 'NN'),
#  ('conjoint', 'NN'),
#  ('staff', 'NN'),
#  ('relation', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('home', 'NN'),
#  ('licensee', 'NN'),
#  ('b', 'NN'),
#  ('pursuant', 'NN'),
#  ('contract', 'NN'),
#  ('agreement', 'NN'),
#  ('licensee', 'NN'),
#  ('c', 'NN'),
#  ('pursuant', 'NN'),
#  ('contract', 'NN'),
#  ('agreement', 'NN'),
#  ('licensee', 'NN'),
#  ('employment', 'NN'),
#  ('agency', 'NN'),
#  ('party', 'NN'),
#  ('decision-maker', 'NN'),
#  ('person', 'NN'),
#  ('consent', 'NN'),
#  ('decision', 'NN'),
#  ('behalf', 'NN'),
#  ('person', 'NN'),
#  ('volunteer', 'NN'),
#  ('person', 'NN'),
#  ('part', 'NN'),
#  ('volunteer', 'NN'),
#  ('program', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('section', 'NN'),
#  ('wage', 'NN'),
#  ('salary', 'NN'),
#  ('work', 'NN'),
#  ('program', 'NN'),
#  ('bénévole', 'NN'),
#  ('ss', 'NN'),
#  ('interest', 'NN'),
#  ('meaning', 'NN'),
#  ('interest', 'NN'),
#  ('person', 'NN'),
#  ('interest', 'NN'),
#  ('licensee', 'NN'),
#  ('person', 'NN'),
#  ('respect', 'NN'),
#  ('licensee', 'NN'),
#  ('corporation', 'NN'),
#  ('i', 'NN'),
#  ('cent', 'NN'),
#  ('equity', 'NN'),
#  ('ii', 'NN'),
#  ('voting', 'NN'),
#  ('sufficient', 'NN'),
#  ('management', 'NN'),
#  ('licensee', 'NN'),
#  ('b', 'NN'),
#  ('right', 'NN'),
#  ('ability', 'NN'),
#  ('management', 'NN'),
#  ('licensee', 'NN'),
#  ('corporation', 'NN'),
#  ('generality', 'NN'),
#  ('subsection', 'NN'),
#  ('person', 'NN'),
#  ('interest', 'NN'),
#  ('licensee', 'NN'),
#  ('person', 'NN'),
#  ('interest', 'NN'),
#  ('person', 'NN'),
#  ('interest', 'NN'),
#  ('licensee', 'NN'),
#  ('subsection', 'NN'),
#  ('person', 'NN'),
#  ('associate', 'NN'),
#  ('person', 'NN'),
#  ('person', 'NN'),
#  ('corporation', 'NN'),
#  ('person', 'NN'),
#  ('officer', 'NN'),
#  ('director', 'NN'),
#  ('b', 'NN'),
#  ('person', 'NN'),
#  ('partnership', 'NN'),
#  ('person', 'NN'),
#  ('partner', 'NN'),
#  ('c', 'NN'),
#  ('person', 'NN'),
#  ('corporation', 'NN'),
#  ('person', 'NN'),
#  ('d', 'NN'),
#  ('person', 'NN'),
#  ('individual', 'NN'),
#  ('corporation', 'NN'),
#  ('person', 'NN'),
#  ('e', 'NN'),
#  ('voting', 'NN'),
#  ('trust', 'NN'),
#  ('trust', 'NN'),
#  ('corporation', 'NN'),
#  ('f', 'NN'),
#  ('person', 'NN'),
#  ('father', 'NN'),
#  ('mother', 'NN'),
#  ('brother', 'NN'),
#  ('sister', 'NN'),
#  ('child', 'NN'),
#  ('spouse', 'NN'),
#  ('person', 'NN'),
#  ('relative', 'NN'),
#  ('home', 'NN'),
#  ('person', 'NN'),
#  ('g', 'NN'),
#  ('meaning', 'NN'),
#  ('person', 'NN'),
#  ('number', 'NN'),
#  ('equity', 'NN'),
#  ('corporation', 'NN'),
#  ('number', 'NN'),
#  ('total', 'NN'),
#  ('share', 'NN'),
#  ('right', 'NN'),
#  ('vote', 'NN'),
#  ('number', 'NN'),
#  ('number', 'NN'),
#  ('Meaning', 'NN'),
#  ('explain', 'NN'),
#  ('adviser', 'NN'),
#  ('person', 'NN'),
#  ('matter', 'NN'),
#  ('resident', 'NN'),
#  ('applicant', 'NN'),
#  ('admission', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('requirement', 'NN'),
#  ('matter', 'NN'),
#  ('ability', 'NN'),
#  ('manner', 'NN'),
#  ('person', 'NN'),
#  ('explanation', 'NN'),
#  ('person', 'NN'),
#  ('Section', 'NN'),
#  ('date', 'NN'),
#  ('force', 'NN'),
#  ('d/m/y', 'NN'),
#  ('force', 'NN'),
#  ('part', 'NN'),
#  ('ii', 'NN'),
#  ('care', 'NN'),
#  ('licensee', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('courtesy', 'NN'),
#  ('respect', 'NN'),
#  ('way', 'NN'),
#  ('resident', 'NN'),
#  ('individuality', 'NN'),
#  ('resident', 'NN'),
#  ('dignity', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('abuse', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('licensee', 'NN'),
#  ('staff', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('manner', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('environment', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('citizen', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('resident', 'NN'),
#  ('care', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('privacy', 'NN'),
#  ('treatment', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('participation', 'NN'),
#  ('decision-making', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('room', 'NN'),
#  ('subject', 'NN'),
#  ('safety', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('development', 'NN'),
#  ('implementation', 'NN'),
#  ('review', 'NN'),
#  ('revision', 'NN'),
#  ('plan', 'NN'),
#  ('care', 'NN'),
#  ('ii', 'NN'),
#  ('consent', 'NN'),
#  ('treatment', 'NN'),
#  ('care', 'NN'),
#  ('consent', 'NN'),
#  ('law', 'NN'),
#  ('consent', 'NN'),
#  ('iii', 'NN'),
#  ('decision', 'NN'),
#  ('aspect', 'NN'),
#  ('care', 'NN'),
#  ('decision', 'NN'),
#  ('admission', 'NN'),
#  ('discharge', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('unit', 'NN'),
#  ('opinion', 'NN'),
#  ('regard', 'NN'),
#  ('Note', 'NN'),
#  ('day', 'NN'),
#  ('proclamation', 'NN'),
#  ('iii', 'NN'),
#  ('subsection', 'NN'),
#  ('unit', 'NN'),
#  ('iv', 'NN'),
#  ('health', 'NN'),
#  ('information', 'NN'),
#  ('meaning', 'NN'),
#  ('confidential', 'NN'),
#  ('accordance', 'NN'),
#  ('access', 'NN'),
#  ('health', 'NN'),
#  ('information', 'NN'),
#  ('plan', 'NN'),
#  ('care', 'NN'),
#  ('accordance', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('care', 'NN'),
#  ('assistance', 'NN'),
#  ('independence', 'NN'),
#  ('care', 'NN'),
#  ('philosophy', 'NN'),
#  ('independence', 'NN'),
#  ('extent', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('Note', 'NN'),
#  ('day', 'NN'),
#  ('proclamation', 'NN'),
#  ('subsection', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('confidence', 'NN'),
#  ('choice', 'NN'),
#  ('consult', 'NN'),
#  ('person', 'NN'),
#  ('interference', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('family', 'NN'),
#  ('day', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('person', 'NN'),
#  ('information', 'NN'),
#  ('transfer', 'NN'),
#  ('hospitalization', 'NN'),
#  ('resident', 'NN'),
#  ('person', 'NN'),
#  ('information', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('behalf', 'NN'),
#  ('interference', 'NN'),
#  ('fear', 'NN'),
#  ('coercion', 'NN'),
#  ('discrimination', 'NN'),
#  ('reprisal', 'NN'),
#  ('resident', 'NN'),
#  ('anyone', 'NN'),
#  ('ii', 'NN'),
#  ('iii', 'NN'),
#  ('licensee', 'NN'),
#  ('licensee', 'NN'),
#  ('corporation', 'NN'),
#  ('corporation', 'NN'),
#  ('case', 'NN'),
#  ('home', 'NN'),
#  ('member', 'NN'),
#  ('committee', 'NN'),
#  ('management', 'NN'),
#  ('home', 'NN'),
#  ('section', 'NN'),
#  ('board', 'NN'),
#  ('management', 'NN'),
#  ('home', 'NN'),
#  ('section', 'NN'),
#  ('iv', 'NN'),
#  ('staff', 'NN'),
#  ('government', 'NN'),
#  ('person', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('life', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('spouse', 'NN'),
#  ('person', 'NN'),
#  ('room', 'NN'),
#  ('privacy', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('share', 'NN'),
#  ('room', 'NN'),
#  ('resident', 'NN'),
#  ('accommodation', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('assistance', 'NN'),
#  ('licensee', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('writing', 'NN'),
#  ('law', 'NN'),
#  ('rule', 'NN'),
#  ('policy', 'NN'),
#  ('affecting', 'NN'),
#  ('resident', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('resident', 'NN'),
#  ('capacity', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('access', 'NN'),
#  ('order', 'NN'),
#  ('activity', 'NN'),
#  ('setting', 'NN'),
#  ('resident', 'NN'),
#  ('right', 'NN'),
#  ('friend', 'NN'),
#  ('family', 'NN'),
#  ('member', 'NN'),
#  ('person', 'NN'),
#  ('importance', 'NN'),
#  ('meeting', 'NN'),
#  ('licensee', 'NN'),
#  ('staff', 'NN'),
#  ('home', 'NN'),
#  ('guide', 'NN'),
#  ('interpretation', 'NN'),
#  ('generality', 'NN'),
#  ('principle', 'NN'),
#  ('objective', 'NN'),
#  ('resident', 'NN'),
#  ('subsection', 'NN'),
#  ('agreement', 'NN'),
#  ('licensee', 'NN'),
#  ('agent', 'NN'),
#  ('agreement', 'NN'),
#  ('licensee', 'NN'),
#  ('resident', 'NN'),
#  ('resident', 'NN'),
#  ('decision-maker', 'NN'),
#  ('Enforcement', 'NN'),
#  ('resident', 'NN'),
#  ('resident', 'NN'),
#  ('licensee', 'NN'),
#  ('resident', 'NN'),
#  ('licensee', 'NN'),
#  ('contract', 'NN'),
#  ('licensee', 'NN'),
#  ('licensee', 'NN'),
#  ('Section', 'NN'),
#  ('date', 'NN'),
#  ('force', 'NN'),
#  ('d/m/y', 'NN'),
#  ('force', 'NN'),
#  ('statement', 'NN'),
#  ('Every', 'NN'),
#  ('licensee', 'NN'),
#  ('mission', 'NN'),
#  ('statement', 'NN'),
#  ('licensee', 'NN'),
#  ('care', 'NN'),
#  ('purpose', 'NN'),
#  ('philosophy', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('b', 'NN'),
#  ('purpose', 'NN'),
#  ('philosophy', 'NN'),
#  ('care', 'NN'),
#  ('mission', 'NN'),
#  ('statement', 'NN'),
#  ('practice', 'NN'),
#  ('operation', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('consistency', 'NN'),
#  ('licensee', 'NN'),
#  ('mission', 'NN'),
#  ('statement', 'NN'),
#  ('principle', 'NN'),
#  ('licensee', 'NN'),
#  ('mission', 'NN'),
#  ('statement', 'NN'),
#  ('collaboration', 'NN'),
#  ('staff', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('mission', 'NN'),
#  ('statement', 'NN'),
#  ('licensee', 'NN'),
#  ('staff', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('environment', 'NN'),
#  ('licensee', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('home', 'NN'),
#  ('environment', 'NN'),
#  ('Plan', 'NN'),
#  ('care', 'NN'),
#  ('licensee', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('plan', 'NN'),
#  ('care', 'NN'),
#  ('resident', 'NN'),
#  ('care', 'NN'),
#  ('resident', 'NN'),
#  ('b', 'NN'),
#  ('care', 'NN'),
#  ('c', 'NN'),
#  ('staff', 'NN'),
#  ('care', 'NN'),
#  ('resident', 'NN'),
#  ('assessment', 'NN'),
#  ('resident', 'NN'),
#  ('licensee', 'NN'),
#  ('care', 'NN'),
#  ('plan', 'NN'),
#  ('care', 'NN'),
#  ('assessment', 'NN'),
#  ('resident', 'NN'),
#  ('resident', 'NN'),
#  ('Plan', 'NN'),
#  ('care', 'NN'),
#  ('licensee', 'NN'),
#  ('plan', 'NN'),
#  ('care', 'NN'),
#  ('care', 'NN'),
#  ('nursing', 'NN'),
#  ('support', 'NN'),
#  ('care', 'NN'),
#  ('Integration', 'NN'),
#  ('care', 'NN'),
#  ('licensee', 'NN'),
#  ('staff', 'NN'),
#  ('care', 'NN'),
#  ('collaborate', 'NN'),
#  ('assessment', 'NN'),
#  ('resident', 'NN'),
#  ('b', 'NN'),
#  ('development', 'NN'),
#  ('implementation', 'NN'),
#  ('plan', 'NN'),
#  ('care', 'NN'),
#  ('care', 'NN'),
#  ('Involvement', 'NN'),
#  ('resident', 'NN'),
#  ('licensee', 'NN'),
#  ('resident', 'NN'),
#  ('resident', 'NN'),
#  ('decision-maker', 'NN'),
#  ('resident', 'NN'),
#  ('substitute', 'NN'),
#  ('decision-maker', 'NN'),
#  ('opportunity', 'NN'),
#  ('development', 'NN'),
#  ('implementation', 'NN'),
#  ('resident', 'NN'),
#  ('plan', 'NN'),
#  ('care', 'NN'),
#  ('plan', 'NN'),
#  ('care', 'NN'),
#  ('resident', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('licensee', 'NN'),
#  ('resident', 'NN'),
#  ('plan', 'NN'),
#  ('care', 'NN'),
#  ('assessment', 'NN'),
#  ('assessment', 'NN'),
#  ('information', 'NN'),
#  ('co-ordinator', 'NN'),
#  ('section', 'NN'),
#  ('Duty', 'NN'),
#  ...]

# %%
tokens_tagged_nouns=list(filter(  lambda x: x[1][0:2]=="NN", tokens_tagged))

# %%
tokens_tagged_nouns
# Out:
# [('Français', 'NNP'),
#  ('Long-Term', 'NNP'),
#  ('Care', 'NNP'),
#  ('Homes', 'NNP'),
#  ('Act', 'NNP'),
#  ('S.o', 'NNP'),
#  ('chapter', 'NN'),
#  ('Consolidation', 'NNP'),
#  ('Period', 'NNP'),
#  ('November', 'NNP'),
#  ('currency', 'NN'),
#  ('date', 'NN'),
#  ('amendment', 'NN'),
#  ('see', 'NN'),
#  ('Table', 'NN'),
#  ('Public', 'NNP'),
#  ('Statute', 'NNP'),
#  ('Provisions', 'NNP'),
#  ('Repealed', 'NNP'),
#  ('Section', 'NNP'),
#  ('Legislation', 'NNP'),
#  ('Act', 'NNP'),
#  ('History', 'NN'),
#  ('Table', 'NNP'),
#  ('Public', 'NNP'),
#  ('Statute', 'NNP'),
#  ('Provisions', 'NNP'),
#  ('Repealed', 'NNP'),
#  ('Section', 'NNP'),
#  ('Legislation', 'NNP'),
#  ('Act', 'NNP'),
#  ('Sched', 'NNP'),
#  ('Sched', 'NNP'),
#  ('Sched', 'NNP'),
#  ('CTS', 'NNP'),
#  ('AL', 'NNP'),
#  ('Sched', 'NNP'),
#  ('Sched', 'NNP'),
#  ('CONTENTS', 'NNP'),
#  ('PART', 'NNP'),
#  ('FUNDAMENTAL', 'NNP'),
#  ('PRINCIPLE', 'NNP'),
#  ('AND', 'NNP'),
#  ('INTERPRETATION', 'NNP'),
#  ('Home', 'NN'),
#  ('principle', 'NN'),
#  ('Interpretation', 'NNP'),
#  ('PART', 'NNP'),
#  ('II', 'NNP'),
#  ('RESIDENTS', 'NNP'),
#  ('RIGHTS', 'NN'),
#  ('CARE', 'NNP'),
#  ('AND', 'NNP'),
#  ('SERVICES', 'NNP'),
#  ('Residents', 'NNP'),
#  ('Bill', 'NNP'),
#  ('Rights', 'NNPS'),
#  ('Residents', 'NNS'),
#  ('Bill', 'NNP'),
#  ('Rights', 'NNPS'),
#  ('Mission', 'NNP'),
#  ('Statement', 'NNP'),
#  ('Mission', 'NN'),
#  ('statement', 'NN'),
#  ('Safe', 'NNP'),
#  ('Secure', 'NNP'),
#  ('Home', 'NNP'),
#  ('Home', 'NN'),
#  ('environment', 'NN'),
#  ('Plan', 'NN'),
#  ('Care', 'NNP'),
#  ('Plan', 'NN'),
#  ('care', 'NN'),
#  ('Consent', 'NNP'),
#  ('Care', 'NNP'),
#  ('Services', 'NNPS'),
#  ('Nursing', 'NN'),
#  ('support', 'NN'),
#  ('services', 'NNS'),
#  ('Restorative', 'NNP'),
#  ('care', 'NN'),
#  ('activities', 'NNS'),
#  ('Dietary', 'NNP'),
#  ('services', 'NNS'),
#  ('hydration', 'NN'),
#  ('Medical', 'NNP'),
#  ('services', 'NNS'),
#  ('Information', 'NN'),
#  ('assistance', 'NN'),
#  ('practices', 'NNS'),
#  ('Accommodation', 'NN'),
#  ('services', 'NNS'),
#  ('Volunteer', 'NNP'),
#  ('program', 'NN'),
#  ('care', 'NN'),
#  ('standards', 'NNS'),
#  ('Standards', 'NNS'),
#  ('programs', 'NNS'),
#  ('services', 'NNS'),
#  ('Prevention', 'NNP'),
#  ('Abuse', 'NNP'),
#  ('Neglect', 'NNP'),
#  ('Duty', 'NN'),
#  ('Policy', 'NN'),
#  ('tolerance', 'NN'),
#  ('Reporting', 'NNP'),
#  ('Complaints', 'NNP'),
#  ('Complaints', 'NNS'),
#  ('licensee', 'NN'),
#  ('complaints', 'NNS'),
#  ('Licensee', 'NNP'),
#  ('respond', 'NN'),
#  ('act', 'NN'),
#  ('matters', 'NNS'),
#  ('Director', 'NNP'),
#  ('Inspections', 'NNS'),
#  ('inquiries', 'NNS'),
#  ('information', 'NN'),
#  ('Director', 'NNP'),
#  ('protection', 'NN'),
#  ('Complaint', 'NN'),
#  ('Ontario', 'NNP'),
#  ('Labour', 'NNP'),
#  ('Relations', 'NNP'),
#  ('Board', 'NNP'),
#  ('Obstruction', 'NNP'),
#  ('information', 'NN'),
#  ('inspectors', 'NNS'),
#  ('Director', 'NNP'),
#  ('Minimizing', 'NNP'),
#  ('Policy', 'NN'),
#  ('restraining', 'NN'),
#  ('residents', 'NNS'),
#  ('Protection', 'NN'),
#  ('Protection', 'NN'),
#  ('Confining', 'NNP'),
#  ('devices', 'NNS'),
#  ('limit', 'NN'),
#  ('movement', 'NN'),
#  ('Records', 'NNS'),
#  ('restraining', 'NN'),
#  ('residents', 'NNS'),
#  ('devices', 'NNS'),
#  ('movement', 'NN'),
#  ('law', 'NN'),
#  ('duty', 'NN'),
#  ('Office', 'NNP'),
#  ('Long-Term', 'NNP'),
#  ('Care', 'NNP'),
#  ('Homes', 'NNP'),
#  ('Resident', 'NNP'),
#  ('Family', 'NNP'),
#  ('Adviser', 'NNP'),
#  ('Office', 'NN'),
#  ('Long-Term', 'NNP'),
#  ('Care', 'NNP'),
#  ('Homes', 'NNP'),
#  ('Resident', 'NNP'),
#  ('Family', 'NNP'),
#  ('Adviser', 'NNP'),
#  ('Regulations', 'NNP'),
#  ('Regulations', 'NNS'),
#  ('PART', 'NNP'),
#  ('III', 'NNP'),
#  ('ADMISSION', 'NNP'),
#  ('OF', 'NNP'),
#  ('RESIDENTS', 'NNP'),
#  ('Application', 'NN'),
#  ('Part', 'NNP'),
#  ('Designation', 'NN'),
#  ('co-ordinators', 'NNS'),
#  ('co-ordinator', 'NN'),
#  ('Act', 'NNP'),
#  ('Requirements', 'NNS'),
#  ('admission', 'NN'),
#  ('home', 'NN'),
#  ('Eligibility', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('admission', 'NN'),
#  ('Authorization', 'NN'),
#  ('admission', 'NN'),
#  ('home', 'NN'),
#  ('Elements', 'NNS'),
#  ('consent', 'NN'),
#  ('decision-maker', 'NN'),
#  ('person', 'NN'),
#  ('Transfer', 'NN'),
#  ('application', 'NN'),
#  ('Controls', 'NNS'),
#  ('licensee', 'NN'),
#  ('Suspension', 'NN'),
#  ('admissions', 'NNS'),
#  ('risk', 'NN'),
#  ('harm', 'NN'),
#  ('Preference', 'NN'),
#  ('veterans', 'NNS'),
#  ('Immunity', 'NNP'),
#  ('placement', 'NN'),
#  ('co-ordinator', 'NN'),
#  ('employees', 'NNS'),
#  ('agents', 'NNS'),
#  ('ineligibility', 'NN'),
#  ('Appeal', 'NN'),
#  ('Divisional', 'NNP'),
#  ('Court', 'NNP'),
#  ('Regulations', 'NNS'),
#  ('PART', 'NNP'),
#  ('IV', 'NNP'),
#  ('COUNCILS', 'NNP'),
#  ('Residents', 'NNP'),
#  ('Council', 'NNP'),
#  ('Residents', 'NNS'),
#  ('Council', 'NNP'),
#  ('Powers', 'NNS'),
#  ('Residents', 'NNP'),
#  ('Council', 'NNP'),
#  ('Residents', 'NNS'),
#  ('Council', 'NNP'),
#  ('Family', 'NNP'),
#  ('Council', 'NNP'),
#  ('Council', 'NNP'),
#  ('Powers', 'NNS'),
#  ('Family', 'NNP'),
#  ('Council', 'NNP'),
#  ('Council', 'NNP'),
#  ('General', 'NNP'),
#  ('Councils', 'NNP'),
#  ('Licensee', 'NNP'),
#  ('duty', 'NN'),
#  ('Council', 'NNP'),
#  ('Attendance', 'NN'),
#  ('meetings', 'NNS'),
#  ('licensees', 'NNS'),
#  ('staff', 'NN'),
#  ('etc', 'NN'),
#  ('interference', 'NN'),
#  ('licensee', 'NN'),
#  ('Immunity', 'NNP'),
#  ('Council', 'NN'),
#  ('members', 'NNS'),
#  ('assistants', 'NNS'),
#  ('Duty', 'NN'),
#  ('licensee', 'NN'),
#  ('Councils', 'NNP'),
#  ('Regulations', 'NNS'),
#  ('PART', 'NNP'),
#  ('V', 'NNP'),
#  ('OPERATION', 'NNP'),
#  ('OF', 'NNP'),
#  ('HOMES', 'NNP'),
#  ('Directors', 'NNP'),
#  ('Officers', 'NNP'),
#  ('Staff', 'NNP'),
#  ('Duties', 'NNS'),
#  ('directors', 'NNS'),
#  ('officers', 'NNS'),
#  ('corporation', 'NN'),
#  ('Administrator', 'NN'),
#  ('Director', 'NN'),
#  ('Nursing', 'NN'),
#  ('Personal', 'NNP'),
#  ('Care', 'NNP'),
#  ('Medical', 'NNP'),
#  ('Director', 'NNP'),
#  ('Staff', 'NNP'),
#  ('Continuity', 'NN'),
#  ('care', 'NN'),
#  ('limit', 'NN'),
#  ('agency', 'NN'),
#  ('staff', 'NN'),
#  ('measures', 'NNS'),
#  ('Orientation', 'NN'),
#  ('volunteers', 'NNS'),
#  ('Residents', 'NNP'),
#  ('Information', 'NN'),
#  ('Agreements', 'NNP'),
#  ('Information', 'NN'),
#  ('residents', 'NNS'),
#  ('information', 'NN'),
#  ('documents', 'NNS'),
#  ('agreements', 'NNS'),
#  ('Agreement', 'NN'),
#  ('withdrawal', 'NN'),
#  ('consent', 'NN'),
#  ('Coercion', 'NN'),
#  ('General', 'NNP'),
#  ('Management', 'NNP'),
#  ('quality', 'NN'),
#  ('improvement', 'NN'),
#  ('Satisfaction', 'NNP'),
#  ('survey', 'NN'),
#  ('Infection', 'NN'),
#  ('prevention', 'NN'),
#  ('control', 'NN'),
#  ('program', 'NN'),
#  ('Emergency', 'NN'),
#  ('Reports', 'NNS'),
#  ('Regulations', 'NNPS'),
#  ('Regulations', 'NNS'),
#  ('PART', 'NNP'),
#  ('VI', 'NNP'),
#  ('FUNDING', 'NNP'),
#  ('Resident', 'NN'),
#  ('charges', 'NNS'),
#  ('Accounts', 'NNS'),
#  ('records', 'NNS'),
#  ('Non-arm', 'NN'),
#  ('length', 'NN'),
#  ('transactions', 'NNS'),
#  ('limitation', 'NN'),
#  ('Regulations', 'NNS'),
#  ('PART', 'NNP'),
#  ('VII', 'NNP'),
#  ('LICENSING', 'NNP'),
#  ('Licence', 'NN'),
#  ('interest', 'NN'),
#  ('need', 'NN'),
#  ('interest', 'NN'),
#  ('licence', 'NN'),
#  ('Limitations', 'NNS'),
#  ('eligibility', 'NN'),
#  ('licence', 'NN'),
#  ('Issue', 'NN'),
#  ('licence', 'NN'),
#  ('licence', 'NN'),
#  ('Conditions', 'NNS'),
#  ('licence', 'NN'),
#  ('licence', 'NN'),
#  ('Notice', 'NN'),
#  ('end', 'NN'),
#  ('term', 'NN'),
#  ('Beds', 'NNS'),
#  ('licence', 'NN'),
#  ('Transfers', 'NNS'),
#  ('limitation', 'NN'),
#  ('consultation', 'NN'),
#  ('Exercise', 'NN'),
#  ('security', 'NN'),
#  ('interests', 'NNS'),
#  ('Notice', 'NNP'),
#  ('interest', 'NN'),
#  ('Management', 'NN'),
#  ('contracts', 'NNS'),
#  ('licences', 'NNS'),
#  ('emergency', 'NN'),
#  ('term', 'NN'),
#  ('authorizations', 'NNS'),
#  ('Amendments', 'NNS'),
#  ('consent', 'NN'),
#  ('process', 'NN'),
#  ('appeal', 'NN'),
#  ('Regulations', 'NNS'),
#  ('PART', 'NNP'),
#  ('VIII', 'NNP'),
#  ('MUNICIPAL', 'NNP'),
#  ('HOMES', 'NNP'),
#  ('AND', 'NNP'),
#  ('FIRST', 'NNP'),
#  ('NATIONS', 'NNP'),
#  ('HOMES', 'NNP'),
#  ('Interpretation', 'NNP'),
#  ('Interpretation', 'NN'),
#  ('Southern', 'NNP'),
#  ('Homes', 'NNP'),
#  ('homes', 'NNS'),
#  ('homes', 'NNS'),
#  ('Agreement', 'NN'),
#  ('home', 'NN'),
#  ('Northern', 'NNP'),
#  ('Homes', 'NNP'),
#  ('Northern', 'NNP'),
#  ('homes', 'NNS'),
#  ('homes', 'NNS'),
#  ('Agreement', 'NN'),
#  ('home', 'NN'),
#  ('district', 'NN'),
#  ('home', 'NN'),
#  ('board', 'NN'),
#  ('management', 'NN'),
#  ('Operating', 'NN'),
#  ('costs', 'NNS'),
#  ('apportionment', 'NN'),
#  ('board', 'NN'),
#  ('management', 'NN'),
#  ('Capital', 'NN'),
#  ('costs', 'NNS'),
#  ('apportionment', 'NN'),
#  ('board', 'NN'),
#  ('management', 'NN'),
#  ('Regulations', 'NNS'),
#  ('apportionments', 'NNS'),
#  ('boards', 'NNS'),
#  ('management', 'NN'),
#  ('First', 'NNP'),
#  ('Nations', 'NNP'),
#  ('Homes', 'NNP'),
#  ('Nations', 'NNPS'),
#  ('homes', 'NNS'),
#  ('General', 'NNP'),
#  ('Approval', 'NN'),
#  ('Application', 'NN'),
#  ('Part', 'NNP'),
#  ('VII', 'NNP'),
#  ('Committee', 'NNP'),
#  ('management', 'NN'),
#  ('appointment', 'NN'),
#  ('Trust', 'NNP'),
#  ('funds', 'NNS'),
#  ('information', 'NN'),
#  ('disclosure', 'NN'),
#  ('inspectors', 'NNS'),
#  ('Director', 'NN'),
#  ('orders', 'NNS'),
#  ('renovations', 'NNS'),
#  ('Director', 'NN'),
#  ('control', 'NN'),
#  ('consent', 'NN'),
#  ('control', 'NN'),
#  ('grounds', 'NNS'),
#  ('exercise', 'NN'),
#  ('power', 'NN'),
#  ('Powers', 'NNS'),
#  ('control', 'NN'),
#  ('Regulations', 'NNS'),
#  ('PART', 'NNP'),
#  ('IX', 'NNP'),
#  ('COMPLIANCE', 'NNP'),
#  ('AND', 'NNP'),
#  ('ENFORCEMENT', 'NNP'),
#  ('Inspections', 'NNP'),
#  ('Appointment', 'NN'),
#  ('inspectors', 'NNS'),
#  ('Purpose', 'NNP'),
#  ('inspection', 'NN'),
#  ('inspection', 'NN'),
#  ('Inspections', 'NNS'),
#  ('councils', 'NNS'),
#  ('Powers', 'NNS'),
#  ('entry', 'NN'),
#  ('Powers', 'NNS'),
#  ('inspection', 'NN'),
#  ('Inspection', 'NNP'),
#  ('report', 'NN'),
#  ('Obstruction', 'NN'),
#  ('Enforcement', 'NN'),
#  ('Actions', 'NNS'),
#  ('inspector', 'NN'),
#  ('Compliance', 'NN'),
#  ('orders', 'NNS'),
#  ('Work', 'NN'),
#  ('activity', 'NN'),
#  ('orders', 'NNS'),
#  ('Order', 'NN'),
#  ('funding', 'NN'),
#  ('management', 'NN'),
#  ('orders', 'NNS'),
#  ('Notice', 'NNP'),
#  ('penalty', 'NN'),
#  ('Revocation', 'NN'),
#  ('Interim', 'NNP'),
#  ('manager', 'NN'),
#  ('rules', 'NNS'),
#  ('employees', 'NNS'),
#  ('Minister', 'NNP'),
#  ('suspension', 'NN'),
#  ('diligence', 'NN'),
#  ('orders', 'NNS'),
#  ('penalties', 'NNS'),
#  ('order', 'NN'),
#  ('notice', 'NN'),
#  ('Enforcement', 'NNP'),
#  ('Acts', 'NNS'),
#  ('Order', 'NN'),
#  ('notice', 'NN'),
#  ('bar', 'NN'),
#  ('conviction', 'NN'),
#  ('Form', 'NNP'),
#  ('service', 'NN'),
#  ('orders', 'NNS'),
#  ('notices', 'NNS'),
#  ('court', 'NN'),
#  ('Offence', 'NNP'),
#  ('Reviews', 'NNP'),
#  ('Appeals', 'NNP'),
#  ('Review', 'NNP'),
#  ('inspector', 'NN'),
#  ('order', 'NN'),
#  ('notice', 'NN'),
#  ('Appeal', 'NN'),
#  ('order', 'NN'),
#  ('notice', 'NN'),
#  ('decision', 'NN'),
#  ('appeal', 'NN'),
#  ('stay', 'NN'),
#  ('order', 'NN'),
#  ('decision', 'NN'),
#  ('Parties', 'NNS'),
#  ('Decision', 'NN'),
#  ('Appeal', 'NNP'),
#  ('Board', 'NNP'),
#  ('court', 'NN'),
#  ('Recognition', 'NN'),
#  ('Reports', 'NNS'),
#  ('Copy', 'NNP'),
#  ('constitutes', 'NNS'),
#  ('evidence', 'NN'),
#  ('Regulations', 'NNS'),
#  ('PART', 'NNP'),
#  ('X', 'NNP'),
#  ('ADMINISTRATION', 'NNP'),
#  ('MISCELLANEOUS', 'NNP'),
#  ('AND', 'NNP'),
#  ('TRANSITION', 'NNP'),
#  ('Directives', 'NNS'),
#  ('Minister', 'NNP'),
#  ('Director', 'NNP'),
#  ('appointment', 'NN'),
#  ('orders', 'NNS'),
#  ('information', 'NN'),
#  ('collection', 'NN'),
#  ('Restriction', 'NN'),
#  ('terms', 'NNS'),
#  ('Affidavits', 'NNS'),
#  ('Service', 'NNP'),
#  ('Immunity', 'NN'),
#  ('Penalties', 'NNS'),
#  ('Regulations', 'NNS'),
#  ('consultation', 'NN'),
#  ('regulations', 'NNS'),
#  ('Amendments', 'NNS'),
#  ('provisions', 'NNS'),
#  ('regulations', 'NNS'),
#  ('Transitional', 'NNP'),
#  ('Transition', 'NN'),
#  ('homes', 'NNS'),
#  ('homes', 'NNS'),
#  ('overbeds', 'NNS'),
#  ('Transitional', 'NNP'),
#  ('mission', 'NN'),
#  ('statement', 'NN'),
#  ('Institutions', 'NNP'),
#  ('Act', 'NNP'),
#  ('Transition', 'NN'),
#  ('homes', 'NNS'),
#  ('Homes', 'NNP'),
#  ('Aged', 'NNP'),
#  ('Rest', 'NNP'),
#  ('Homes', 'NNP'),
#  ('Act', 'NNP'),
#  ('cause', 'NN'),
#  ('action', 'NN'),
#  ('enactment', 'NN'),
#  ('Act', 'NNP'),
#  ('Transition', 'NNP'),
#  ('term', 'NN'),
#  ('extension', 'NN'),
#  ('Preamble', 'NNP'),
#  ('people', 'NNS'),
#  ('Ontario', 'NNP'),
#  ('Government', 'NN'),
#  ('care', 'NN'),
#  ('Remain', 'NNP'),
#  ('health', 'NN'),
#  ('well-being', 'NN'),
#  ('Ontarians', 'NNPS'),
#  ('care', 'NN'),
#  ('homes', 'NNS'),
#  ('future', 'NN'),
#  ('Strongly', 'NNP'),
#  ('collaboration', 'NN'),
#  ('respect', 'NN'),
#  ('amongst', 'NN'),
#  ('residents', 'NNS'),
#  ('families', 'NNS'),
#  ('friends', 'NNS'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('providers', 'NNS'),
#  ('service', 'NN'),
#  ('providers', 'NNS'),
#  ('caregivers', 'NNS'),
#  ('volunteers', 'NNS'),
#  ('community', 'NN'),
#  ('governments', 'NNS'),
#  ('care', 'NN'),
#  ('services', 'NNS'),
#  ('needs', 'NNS'),
#  ('resident', 'NN'),
#  ('safety', 'NN'),
#  ('needs', 'NNS'),
#  ('residents', 'NNS'),
#  ('principle', 'NN'),
#  ('access', 'NN'),
#  ('care', 'NN'),
#  ('homes', 'NNS'),
#  ('need', 'NN'),
#  ('Firmly', 'NNP'),
#  ('accountability', 'NN'),
#  ('transparency', 'NN'),
#  ('care', 'NN'),
#  ('homes', 'NNS'),
#  ('way', 'NN'),
#  ('interest', 'NN'),
#  ('public', 'NN'),
#  ('promotes', 'NNS'),
#  ('delivery', 'NN'),
#  ('high-quality', 'NN'),
#  ('services', 'NNS'),
#  ('residents', 'NNS'),
#  ('Firmly', 'NNP'),
#  ('standards', 'NNS'),
#  ('care', 'NN'),
#  ('services', 'NNS'),
#  ('compliance', 'NN'),
#  ('inspection', 'NN'),
#  ('enforcement', 'NN'),
#  ('system', 'NN'),
#  ('responsibility', 'NN'),
#  ('action', 'NN'),
#  ('standards', 'NNS'),
#  ('requirements', 'NNS'),
#  ('Act', 'NNP'),
#  ('care', 'NN'),
#  ('safety', 'NN'),
#  ('security', 'NN'),
#  ('rights', 'NNS'),
#  ('residents', 'NNS'),
#  ('Affirm', 'NNP'),
#  ('commitment', 'NN'),
#  ('quality', 'NN'),
#  ('accommodation', 'NN'),
#  ('environment', 'NN'),
#  ('quality', 'NN'),
#  ('life', 'NN'),
#  ('residents', 'NNS'),
#  ('care', 'NN'),
#  ('homes', 'NNS'),
#  ('care', 'NN'),
#  ('services', 'NNS'),
#  ('diversity', 'NN'),
#  ('communities', 'NNS'),
#  ('Respect', 'NNP'),
#  ('requirements', 'NNS'),
#  ('Language', 'NNP'),
#  ('Services', 'NNP'),
#  ('Act', 'NNP'),
#  ('Ontario', 'NNP'),
#  ('Francophone', 'NNP'),
#  ('community', 'NN'),
#  ('importance', 'NN'),
#  ('delivery', 'NN'),
#  ('care', 'NN'),
#  ('services', 'NNS'),
#  ('residents', 'NNS'),
#  ('environment', 'NN'),
#  ('quality', 'NN'),
#  ('improvement', 'NN'),
#  ('Are', 'NNP'),
#  ('promotion', 'NN'),
#  ('delivery', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('services', 'NNS'),
#  ('organizations', 'NNS'),
#  ('Her', 'NNP'),
#  ('Majesty', 'NNP'),
#  ('advice', 'NN'),
#  ('consent', 'NN'),
#  ('Legislative', 'NNP'),
#  ('Assembly', 'NNP'),
#  ('Province', 'NNP'),
#  ('Ontario', 'NNP'),
#  ('part', 'NN'),
#  ('principLe', 'NN'),
#  ('interpretation', 'NN'),
#  ('Home', 'NN'),
#  ('principle', 'NN'),
#  ('principle', 'NN'),
#  ('interpretation', 'NN'),
#  ('Act', 'NNP'),
#  ('anything', 'NN'),
#  ('Act', 'NNP'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('home', 'NN'),
#  ('residents', 'NNS'),
#  ('place', 'NN'),
#  ('dignity', 'NN'),
#  ('security', 'NN'),
#  ('safety', 'NN'),
#  ('comfort', 'NN'),
#  ('needs', 'NNS'),
#  ('Interpretation', 'NN'),
#  ('Act', 'NNP'),
#  ('abuse', 'NN'),
#  ('relation', 'NN'),
#  ('resident', 'NN'),
#  ('abuse', 'NN'),
#  ('regulations', 'NNS'),
#  ('case', 'NN'),
#  ('traitement', 'NN'),
#  ('Administrator', 'NNP'),
#  ('relation', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('Administrator', 'NNP'),
#  ('home', 'NN'),
#  ('section', 'NN'),
#  ('administrateur', 'NN'),
#  ('du', 'NN'),
#  ('foyer', 'NN'),
#  ('Appeal', 'NNP'),
#  ('Board', 'NNP'),
#  ('Health', 'NNP'),
#  ('Services', 'NNPS'),
#  ('Appeal', 'NNP'),
#  ('Review', 'NNP'),
#  ('Board', 'NNP'),
#  ('Ministry', 'NNP'),
#  ('Health', 'NNP'),
#  ('Long-Term', 'NNP'),
#  ('Care', 'NNP'),
#  ('Appeal', 'NNP'),
#  ('Review', 'NNP'),
#  ('Boards', 'NNP'),
#  ('Act', 'NNP'),
#  ('Commission', 'NNP'),
#  ("d'appel", 'NN'),
#  ('care', 'NN'),
#  ('treatment', 'NN'),
#  ('interventions', 'NNS'),
#  ('soins', 'NNS'),
#  ('Note', 'NN'),
#  ('day', 'NN'),
#  ('proclamation', 'NN'),
#  ('Lieutenant', 'NNP'),
#  ('Governor', 'NNP'),
#  ('subsection', 'NN'),
#  ('Act', 'NNP'),
#  ('definition', 'NN'),
#  ('Sched', 'NNP'),
#  ('confine', 'NN'),
#  ('respect', 'NN'),
#  ('law', 'NN'),
#  ('duty', 'NN'),
#  ('caregiver', 'NN'),
#  ('person', 'NN'),
#  ('section', 'NN'),
#  ('meaning', 'NN'),
#  ('regulations', 'NNS'),
#  ('confiner', 'NN'),
#  ('Director', 'NNP'),
#  ('person', 'NN'),
#  ('section', 'NN'),
#  ('Director', 'NNP'),
#  ('person', 'NN'),
#  ('person', 'NN'),
#  ('Director', 'NNP'),
#  ('purposes', 'NNS'),
#  ('provision', 'NN'),
#  ('term', 'NN'),
#  ('directeur', 'NN'),
#  ('Director', 'NNP'),
#  ('Nursing', 'NNP'),
#  ('Personal', 'NNP'),
#  ('Care', 'NNP'),
#  ('relation', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('Director', 'NNP'),
#  ('Nursing', 'NNP'),
#  ('Personal', 'NNP'),
#  ('Care', 'NNP'),
#  ('home', 'NN'),
#  ('section', 'NN'),
#  ('directeur', 'NN'),
#  ('des', 'NNS'),
#  ('infirmiers', 'NNS'),
#  ('des', 'NNS'),
#  ('soins', 'NNS'),
#  ('personnels', 'NNS'),
#  ('equity', 'NN'),
#  ('share', 'NN'),
#  ('share', 'NN'),
#  ('class', 'NN'),
#  ('shares', 'NNS'),
#  ('corporation', 'NN'),
#  ('voting', 'NN'),
#  ('right', 'NN'),
#  ('circumstances', 'NNS'),
#  ('circumstances', 'NNS'),
#  ('action', 'NN'),
#  ('participante', 'NN'),
#  ('principle', 'NN'),
#  ('principle', 'NN'),
#  ('section', 'NN'),
#  ('principe', 'NN'),
#  ('information', 'NN'),
#  ('decision', 'NN'),
#  ('matter', 'NN'),
#  ('reasonably', 'NN'),
#  ('consequences', 'NNS'),
#  ('decision', 'NN'),
#  ('lack', 'NN'),
#  ('decision', 'NN'),
#  ('intervention', 'NN'),
#  ('action', 'NN'),
#  ('procedure', 'NN'),
#  ('activity', 'NN'),
#  ('outcome', 'NN'),
#  ('condition', 'NN'),
#  ('diagnosis', 'NN'),
#  ('intervention', 'NN'),
#  ('licensee', 'NN'),
#  ('holder', 'NN'),
#  ('licence', 'NN'),
#  ('Act', 'NNP'),
#  ('municipality', 'NN'),
#  ('municipalities', 'NNS'),
#  ('board', 'NN'),
#  ('management', 'NN'),
#  ('home', 'NN'),
#  ('home', 'NN'),
#  ('Nations', 'NNP'),
#  ('home', 'NN'),
#  ('Part', 'NNP'),
#  ('VIII', 'NNP'),
#  ('titulaire', 'NN'),
#  ('health', 'NN'),
#  ('integration', 'NN'),
#  ('network', 'NN'),
#  ('health', 'NN'),
#  ('integration', 'NN'),
#  ('network', 'NN'),
#  ('section', 'NN'),
#  ('Local', 'NNP'),
#  ('Health', 'NNP'),
#  ('System', 'NNP'),
#  ('Integration', 'NNP'),
#  ('Act', 'NNP'),
#  ("d'intégration", 'NN'),
#  ('des', 'NNS'),
#  ('services', 'NNS'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('place', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('Act', 'NNP'),
#  ('home', 'NN'),
#  ('home', 'NN'),
#  ('Nations', 'NNP'),
#  ('home', 'NN'),
#  ('Part', 'NNP'),
#  ('VIII', 'NNP'),
#  ('foyer', 'NN'),
#  ('durée', 'NN'),
#  ('Minister', 'NNP'),
#  ('Minister', 'NNP'),
#  ('Health', 'NNP'),
#  ('Long-Term', 'NNP'),
#  ('Care', 'NNP'),
#  ('responsibility', 'NN'),
#  ('administration', 'NN'),
#  ('Act', 'NNP'),
#  ('Minister', 'NNP'),
#  ('Executive', 'NNP'),
#  ('Council', 'NNP'),
#  ('Act', 'NNP'),
#  ('Minister', 'NNP'),
#  ('Ministry', 'NNP'),
#  ('Ministry', 'NNP'),
#  ('Minister', 'NNP'),
#  ('presides', 'NNS'),
#  ('ministère', 'NN'),
#  ('member', 'NN'),
#  ('College', 'NNP'),
#  ('Physicians', 'NNPS'),
#  ('Surgeons', 'NNP'),
#  ('Ontario', 'NNP'),
#  ('médecin', 'NN'),
#  ('nurse', 'NN'),
#  ('member', 'NN'),
#  ('College', 'NNP'),
#  ('Nurses', 'NNP'),
#  ('Ontario', 'NNP'),
#  ('certificate', 'NN'),
#  ('registration', 'NN'),
#  ('nurse', 'NN'),
#  ('Nursing', 'NNP'),
#  ('Act', 'NNP'),
#  ('autorisée', 'NN'),
#  ('autorisé', 'NN'),
#  ('nurse', 'NN'),
#  ('class', 'NN'),
#  ('nurse', 'NN'),
#  ('certificate', 'NN'),
#  ('registration', 'NN'),
#  ('Nursing', 'NNP'),
#  ('Act', 'NNP'),
#  ('ou', 'NN'),
#  ('infirmier', 'NN'),
#  ('supérieure', 'NN'),
#  ('nurse', 'NN'),
#  ('member', 'NN'),
#  ('College', 'NNP'),
#  ('Nurses', 'NNP'),
#  ('Ontario', 'NNP'),
#  ('certificate', 'NN'),
#  ('registration', 'NN'),
#  ('nurse', 'NN'),
#  ('Nursing', 'NNP'),
#  ('Act', 'NNP'),
#  ('auxiliaire', 'NN'),
#  ('autorisée', 'NN'),
#  ('auxiliaire', 'NN'),
#  ('autorisé', 'NN'),
#  ('Act', 'NNP'),
#  ('requirement', 'NN'),
#  ('Act', 'NNP'),
#  ('regulations', 'NNS'),
#  ('order', 'NN'),
#  ('agreement', 'NN'),
#  ('Act', 'NNP'),
#  ('condition', 'NN'),
#  ('licence', 'NN'),
#  ('Part', 'NNP'),
#  ('VII', 'NNP'),
#  ('approval', 'NN'),
#  ('Part', 'NNP'),
#  ('VIII', 'NNP'),
#  ('condition', 'NN'),
#  ('funding', 'NN'),
#  ('section', 'NN'),
#  ('subsection', 'NN'),
#  ('policy', 'NN'),
#  ('Minister', 'NNP'),
#  ('section', 'NN'),
#  ('exigence', 'NN'),
#  ('que', 'NN'),
#  ('prévoit', 'NN'),
#  ('la', 'NN'),
#  ('resident', 'NN'),
#  ('person', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('résident', 'NN'),
#  ('Residents', 'NNP'),
#  ('Bill', 'NNP'),
#  ('Rights', 'NNPS'),
#  ('list', 'NN'),
#  ('rights', 'NNS'),
#  ('residents', 'NNS'),
#  ('section', 'NN'),
#  ('déclaration', 'NN'),
#  ('droits', 'NNS'),
#  ('des', 'NNS'),
#  ('résidents', 'NNS'),
#  ('rights', 'NNS'),
#  ('adviser', 'NN'),
#  ('person', 'NN'),
#  ('accordance', 'NN'),
#  ('regulations', 'NNS'),
#  ('rights', 'NNS'),
#  ('adviser', 'NN'),
#  ('conseiller', 'NN'),
#  ('matière', 'NN'),
#  ('droits', 'NNS'),
#  ('unit', 'NN'),
#  ('area', 'NN'),
#  ('care', 'NN'),
#  ('home', 'NN'),
#  ('secure', 'NN'),
#  ('unit', 'NN'),
#  ('accordance', 'NN'),
#  ('regulations', 'NNS'),
#  ('Note', 'NN'),
#  ('day', 'NN'),
#  ('proclamation', 'NN'),
#  ('Lieutenant', 'NNP'),
#  ('Governor', 'NNP'),
#  ('definition', 'NN'),
#  ('unit', 'NN'),
#  ('subsection', 'NN'),
#  ('Act', 'NNP'),
#  ('Sched', 'NNP'),
#  ('spouse', 'NN'),
#  ('means', 'NNS'),
#  ('spouse', 'NN'),
#  ('section', 'NN'),
#  ('Family', 'NNP'),
#  ('Law', 'NNP'),
#  ('Act', 'NNP'),
#  ('b', 'NN'),
#  ('persons', 'NNS'),
#  ('conjugal', 'NN'),
#  ('relationship', 'NN'),
#  ('marriage', 'NN'),
#  ('conjoint', 'NN'),
#  ...]

# %%
nouns = list( map(lambda x: x[0],tokens_tagged_nouns) )

# %%
nouns
# Out:
# ['Français',
#  'Long-Term',
#  'Care',
#  'Homes',
#  'Act',
#  'S.o',
#  'chapter',
#  'Consolidation',
#  'Period',
#  'November',
#  'currency',
#  'date',
#  'amendment',
#  'see',
#  'Table',
#  'Public',
#  'Statute',
#  'Provisions',
#  'Repealed',
#  'Section',
#  'Legislation',
#  'Act',
#  'History',
#  'Table',
#  'Public',
#  'Statute',
#  'Provisions',
#  'Repealed',
#  'Section',
#  'Legislation',
#  'Act',
#  'Sched',
#  'Sched',
#  'Sched',
#  'CTS',
#  'AL',
#  'Sched',
#  'Sched',
#  'CONTENTS',
#  'PART',
#  'FUNDAMENTAL',
#  'PRINCIPLE',
#  'AND',
#  'INTERPRETATION',
#  'Home',
#  'principle',
#  'Interpretation',
#  'PART',
#  'II',
#  'RESIDENTS',
#  'RIGHTS',
#  'CARE',
#  'AND',
#  'SERVICES',
#  'Residents',
#  'Bill',
#  'Rights',
#  'Residents',
#  'Bill',
#  'Rights',
#  'Mission',
#  'Statement',
#  'Mission',
#  'statement',
#  'Safe',
#  'Secure',
#  'Home',
#  'Home',
#  'environment',
#  'Plan',
#  'Care',
#  'Plan',
#  'care',
#  'Consent',
#  'Care',
#  'Services',
#  'Nursing',
#  'support',
#  'services',
#  'Restorative',
#  'care',
#  'activities',
#  'Dietary',
#  'services',
#  'hydration',
#  'Medical',
#  'services',
#  'Information',
#  'assistance',
#  'practices',
#  'Accommodation',
#  'services',
#  'Volunteer',
#  'program',
#  'care',
#  'standards',
#  'Standards',
#  'programs',
#  'services',
#  'Prevention',
#  'Abuse',
#  'Neglect',
#  'Duty',
#  'Policy',
#  'tolerance',
#  'Reporting',
#  'Complaints',
#  'Complaints',
#  'licensee',
#  'complaints',
#  'Licensee',
#  'respond',
#  'act',
#  'matters',
#  'Director',
#  'Inspections',
#  'inquiries',
#  'information',
#  'Director',
#  'protection',
#  'Complaint',
#  'Ontario',
#  'Labour',
#  'Relations',
#  'Board',
#  'Obstruction',
#  'information',
#  'inspectors',
#  'Director',
#  'Minimizing',
#  'Policy',
#  'restraining',
#  'residents',
#  'Protection',
#  'Protection',
#  'Confining',
#  'devices',
#  'limit',
#  'movement',
#  'Records',
#  'restraining',
#  'residents',
#  'devices',
#  'movement',
#  'law',
#  'duty',
#  'Office',
#  'Long-Term',
#  'Care',
#  'Homes',
#  'Resident',
#  'Family',
#  'Adviser',
#  'Office',
#  'Long-Term',
#  'Care',
#  'Homes',
#  'Resident',
#  'Family',
#  'Adviser',
#  'Regulations',
#  'Regulations',
#  'PART',
#  'III',
#  'ADMISSION',
#  'OF',
#  'RESIDENTS',
#  'Application',
#  'Part',
#  'Designation',
#  'co-ordinators',
#  'co-ordinator',
#  'Act',
#  'Requirements',
#  'admission',
#  'home',
#  'Eligibility',
#  'care',
#  'home',
#  'admission',
#  'Authorization',
#  'admission',
#  'home',
#  'Elements',
#  'consent',
#  'decision-maker',
#  'person',
#  'Transfer',
#  'application',
#  'Controls',
#  'licensee',
#  'Suspension',
#  'admissions',
#  'risk',
#  'harm',
#  'Preference',
#  'veterans',
#  'Immunity',
#  'placement',
#  'co-ordinator',
#  'employees',
#  'agents',
#  'ineligibility',
#  'Appeal',
#  'Divisional',
#  'Court',
#  'Regulations',
#  'PART',
#  'IV',
#  'COUNCILS',
#  'Residents',
#  'Council',
#  'Residents',
#  'Council',
#  'Powers',
#  'Residents',
#  'Council',
#  'Residents',
#  'Council',
#  'Family',
#  'Council',
#  'Council',
#  'Powers',
#  'Family',
#  'Council',
#  'Council',
#  'General',
#  'Councils',
#  'Licensee',
#  'duty',
#  'Council',
#  'Attendance',
#  'meetings',
#  'licensees',
#  'staff',
#  'etc',
#  'interference',
#  'licensee',
#  'Immunity',
#  'Council',
#  'members',
#  'assistants',
#  'Duty',
#  'licensee',
#  'Councils',
#  'Regulations',
#  'PART',
#  'V',
#  'OPERATION',
#  'OF',
#  'HOMES',
#  'Directors',
#  'Officers',
#  'Staff',
#  'Duties',
#  'directors',
#  'officers',
#  'corporation',
#  'Administrator',
#  'Director',
#  'Nursing',
#  'Personal',
#  'Care',
#  'Medical',
#  'Director',
#  'Staff',
#  'Continuity',
#  'care',
#  'limit',
#  'agency',
#  'staff',
#  'measures',
#  'Orientation',
#  'volunteers',
#  'Residents',
#  'Information',
#  'Agreements',
#  'Information',
#  'residents',
#  'information',
#  'documents',
#  'agreements',
#  'Agreement',
#  'withdrawal',
#  'consent',
#  'Coercion',
#  'General',
#  'Management',
#  'quality',
#  'improvement',
#  'Satisfaction',
#  'survey',
#  'Infection',
#  'prevention',
#  'control',
#  'program',
#  'Emergency',
#  'Reports',
#  'Regulations',
#  'Regulations',
#  'PART',
#  'VI',
#  'FUNDING',
#  'Resident',
#  'charges',
#  'Accounts',
#  'records',
#  'Non-arm',
#  'length',
#  'transactions',
#  'limitation',
#  'Regulations',
#  'PART',
#  'VII',
#  'LICENSING',
#  'Licence',
#  'interest',
#  'need',
#  'interest',
#  'licence',
#  'Limitations',
#  'eligibility',
#  'licence',
#  'Issue',
#  'licence',
#  'licence',
#  'Conditions',
#  'licence',
#  'licence',
#  'Notice',
#  'end',
#  'term',
#  'Beds',
#  'licence',
#  'Transfers',
#  'limitation',
#  'consultation',
#  'Exercise',
#  'security',
#  'interests',
#  'Notice',
#  'interest',
#  'Management',
#  'contracts',
#  'licences',
#  'emergency',
#  'term',
#  'authorizations',
#  'Amendments',
#  'consent',
#  'process',
#  'appeal',
#  'Regulations',
#  'PART',
#  'VIII',
#  'MUNICIPAL',
#  'HOMES',
#  'AND',
#  'FIRST',
#  'NATIONS',
#  'HOMES',
#  'Interpretation',
#  'Interpretation',
#  'Southern',
#  'Homes',
#  'homes',
#  'homes',
#  'Agreement',
#  'home',
#  'Northern',
#  'Homes',
#  'Northern',
#  'homes',
#  'homes',
#  'Agreement',
#  'home',
#  'district',
#  'home',
#  'board',
#  'management',
#  'Operating',
#  'costs',
#  'apportionment',
#  'board',
#  'management',
#  'Capital',
#  'costs',
#  'apportionment',
#  'board',
#  'management',
#  'Regulations',
#  'apportionments',
#  'boards',
#  'management',
#  'First',
#  'Nations',
#  'Homes',
#  'Nations',
#  'homes',
#  'General',
#  'Approval',
#  'Application',
#  'Part',
#  'VII',
#  'Committee',
#  'management',
#  'appointment',
#  'Trust',
#  'funds',
#  'information',
#  'disclosure',
#  'inspectors',
#  'Director',
#  'orders',
#  'renovations',
#  'Director',
#  'control',
#  'consent',
#  'control',
#  'grounds',
#  'exercise',
#  'power',
#  'Powers',
#  'control',
#  'Regulations',
#  'PART',
#  'IX',
#  'COMPLIANCE',
#  'AND',
#  'ENFORCEMENT',
#  'Inspections',
#  'Appointment',
#  'inspectors',
#  'Purpose',
#  'inspection',
#  'inspection',
#  'Inspections',
#  'councils',
#  'Powers',
#  'entry',
#  'Powers',
#  'inspection',
#  'Inspection',
#  'report',
#  'Obstruction',
#  'Enforcement',
#  'Actions',
#  'inspector',
#  'Compliance',
#  'orders',
#  'Work',
#  'activity',
#  'orders',
#  'Order',
#  'funding',
#  'management',
#  'orders',
#  'Notice',
#  'penalty',
#  'Revocation',
#  'Interim',
#  'manager',
#  'rules',
#  'employees',
#  'Minister',
#  'suspension',
#  'diligence',
#  'orders',
#  'penalties',
#  'order',
#  'notice',
#  'Enforcement',
#  'Acts',
#  'Order',
#  'notice',
#  'bar',
#  'conviction',
#  'Form',
#  'service',
#  'orders',
#  'notices',
#  'court',
#  'Offence',
#  'Reviews',
#  'Appeals',
#  'Review',
#  'inspector',
#  'order',
#  'notice',
#  'Appeal',
#  'order',
#  'notice',
#  'decision',
#  'appeal',
#  'stay',
#  'order',
#  'decision',
#  'Parties',
#  'Decision',
#  'Appeal',
#  'Board',
#  'court',
#  'Recognition',
#  'Reports',
#  'Copy',
#  'constitutes',
#  'evidence',
#  'Regulations',
#  'PART',
#  'X',
#  'ADMINISTRATION',
#  'MISCELLANEOUS',
#  'AND',
#  'TRANSITION',
#  'Directives',
#  'Minister',
#  'Director',
#  'appointment',
#  'orders',
#  'information',
#  'collection',
#  'Restriction',
#  'terms',
#  'Affidavits',
#  'Service',
#  'Immunity',
#  'Penalties',
#  'Regulations',
#  'consultation',
#  'regulations',
#  'Amendments',
#  'provisions',
#  'regulations',
#  'Transitional',
#  'Transition',
#  'homes',
#  'homes',
#  'overbeds',
#  'Transitional',
#  'mission',
#  'statement',
#  'Institutions',
#  'Act',
#  'Transition',
#  'homes',
#  'Homes',
#  'Aged',
#  'Rest',
#  'Homes',
#  'Act',
#  'cause',
#  'action',
#  'enactment',
#  'Act',
#  'Transition',
#  'term',
#  'extension',
#  'Preamble',
#  'people',
#  'Ontario',
#  'Government',
#  'care',
#  'Remain',
#  'health',
#  'well-being',
#  'Ontarians',
#  'care',
#  'homes',
#  'future',
#  'Strongly',
#  'collaboration',
#  'respect',
#  'amongst',
#  'residents',
#  'families',
#  'friends',
#  'care',
#  'home',
#  'providers',
#  'service',
#  'providers',
#  'caregivers',
#  'volunteers',
#  'community',
#  'governments',
#  'care',
#  'services',
#  'needs',
#  'resident',
#  'safety',
#  'needs',
#  'residents',
#  'principle',
#  'access',
#  'care',
#  'homes',
#  'need',
#  'Firmly',
#  'accountability',
#  'transparency',
#  'care',
#  'homes',
#  'way',
#  'interest',
#  'public',
#  'promotes',
#  'delivery',
#  'high-quality',
#  'services',
#  'residents',
#  'Firmly',
#  'standards',
#  'care',
#  'services',
#  'compliance',
#  'inspection',
#  'enforcement',
#  'system',
#  'responsibility',
#  'action',
#  'standards',
#  'requirements',
#  'Act',
#  'care',
#  'safety',
#  'security',
#  'rights',
#  'residents',
#  'Affirm',
#  'commitment',
#  'quality',
#  'accommodation',
#  'environment',
#  'quality',
#  'life',
#  'residents',
#  'care',
#  'homes',
#  'care',
#  'services',
#  'diversity',
#  'communities',
#  'Respect',
#  'requirements',
#  'Language',
#  'Services',
#  'Act',
#  'Ontario',
#  'Francophone',
#  'community',
#  'importance',
#  'delivery',
#  'care',
#  'services',
#  'residents',
#  'environment',
#  'quality',
#  'improvement',
#  'Are',
#  'promotion',
#  'delivery',
#  'care',
#  'home',
#  'services',
#  'organizations',
#  'Her',
#  'Majesty',
#  'advice',
#  'consent',
#  'Legislative',
#  'Assembly',
#  'Province',
#  'Ontario',
#  'part',
#  'principLe',
#  'interpretation',
#  'Home',
#  'principle',
#  'principle',
#  'interpretation',
#  'Act',
#  'anything',
#  'Act',
#  'care',
#  'home',
#  'home',
#  'residents',
#  'place',
#  'dignity',
#  'security',
#  'safety',
#  'comfort',
#  'needs',
#  'Interpretation',
#  'Act',
#  'abuse',
#  'relation',
#  'resident',
#  'abuse',
#  'regulations',
#  'case',
#  'traitement',
#  'Administrator',
#  'relation',
#  'care',
#  'home',
#  'Administrator',
#  'home',
#  'section',
#  'administrateur',
#  'du',
#  'foyer',
#  'Appeal',
#  'Board',
#  'Health',
#  'Services',
#  'Appeal',
#  'Review',
#  'Board',
#  'Ministry',
#  'Health',
#  'Long-Term',
#  'Care',
#  'Appeal',
#  'Review',
#  'Boards',
#  'Act',
#  'Commission',
#  "d'appel",
#  'care',
#  'treatment',
#  'interventions',
#  'soins',
#  'Note',
#  'day',
#  'proclamation',
#  'Lieutenant',
#  'Governor',
#  'subsection',
#  'Act',
#  'definition',
#  'Sched',
#  'confine',
#  'respect',
#  'law',
#  'duty',
#  'caregiver',
#  'person',
#  'section',
#  'meaning',
#  'regulations',
#  'confiner',
#  'Director',
#  'person',
#  'section',
#  'Director',
#  'person',
#  'person',
#  'Director',
#  'purposes',
#  'provision',
#  'term',
#  'directeur',
#  'Director',
#  'Nursing',
#  'Personal',
#  'Care',
#  'relation',
#  'care',
#  'home',
#  'Director',
#  'Nursing',
#  'Personal',
#  'Care',
#  'home',
#  'section',
#  'directeur',
#  'des',
#  'infirmiers',
#  'des',
#  'soins',
#  'personnels',
#  'equity',
#  'share',
#  'share',
#  'class',
#  'shares',
#  'corporation',
#  'voting',
#  'right',
#  'circumstances',
#  'circumstances',
#  'action',
#  'participante',
#  'principle',
#  'principle',
#  'section',
#  'principe',
#  'information',
#  'decision',
#  'matter',
#  'reasonably',
#  'consequences',
#  'decision',
#  'lack',
#  'decision',
#  'intervention',
#  'action',
#  'procedure',
#  'activity',
#  'outcome',
#  'condition',
#  'diagnosis',
#  'intervention',
#  'licensee',
#  'holder',
#  'licence',
#  'Act',
#  'municipality',
#  'municipalities',
#  'board',
#  'management',
#  'home',
#  'home',
#  'Nations',
#  'home',
#  'Part',
#  'VIII',
#  'titulaire',
#  'health',
#  'integration',
#  'network',
#  'health',
#  'integration',
#  'network',
#  'section',
#  'Local',
#  'Health',
#  'System',
#  'Integration',
#  'Act',
#  "d'intégration",
#  'des',
#  'services',
#  'care',
#  'home',
#  'place',
#  'care',
#  'home',
#  'Act',
#  'home',
#  'home',
#  'Nations',
#  'home',
#  'Part',
#  'VIII',
#  'foyer',
#  'durée',
#  'Minister',
#  'Minister',
#  'Health',
#  'Long-Term',
#  'Care',
#  'responsibility',
#  'administration',
#  'Act',
#  'Minister',
#  'Executive',
#  'Council',
#  'Act',
#  'Minister',
#  'Ministry',
#  'Ministry',
#  'Minister',
#  'presides',
#  'ministère',
#  'member',
#  'College',
#  'Physicians',
#  'Surgeons',
#  'Ontario',
#  'médecin',
#  'nurse',
#  'member',
#  'College',
#  'Nurses',
#  'Ontario',
#  'certificate',
#  'registration',
#  'nurse',
#  'Nursing',
#  'Act',
#  'autorisée',
#  'autorisé',
#  'nurse',
#  'class',
#  'nurse',
#  'certificate',
#  'registration',
#  'Nursing',
#  'Act',
#  'ou',
#  'infirmier',
#  'supérieure',
#  'nurse',
#  'member',
#  'College',
#  'Nurses',
#  'Ontario',
#  'certificate',
#  'registration',
#  'nurse',
#  'Nursing',
#  'Act',
#  'auxiliaire',
#  'autorisée',
#  'auxiliaire',
#  'autorisé',
#  'Act',
#  'requirement',
#  'Act',
#  'regulations',
#  'order',
#  'agreement',
#  'Act',
#  'condition',
#  'licence',
#  'Part',
#  'VII',
#  'approval',
#  'Part',
#  'VIII',
#  'condition',
#  'funding',
#  'section',
#  'subsection',
#  'policy',
#  'Minister',
#  'section',
#  'exigence',
#  'que',
#  'prévoit',
#  'la',
#  'resident',
#  'person',
#  'care',
#  'home',
#  'résident',
#  'Residents',
#  'Bill',
#  'Rights',
#  'list',
#  'rights',
#  'residents',
#  'section',
#  'déclaration',
#  'droits',
#  'des',
#  'résidents',
#  'rights',
#  'adviser',
#  'person',
#  'accordance',
#  'regulations',
#  'rights',
#  'adviser',
#  'conseiller',
#  'matière',
#  'droits',
#  'unit',
#  'area',
#  'care',
#  'home',
#  'secure',
#  'unit',
#  'accordance',
#  'regulations',
#  'Note',
#  'day',
#  'proclamation',
#  'Lieutenant',
#  'Governor',
#  'definition',
#  'unit',
#  'subsection',
#  'Act',
#  'Sched',
#  'spouse',
#  'means',
#  'spouse',
#  'section',
#  'Family',
#  'Law',
#  'Act',
#  'b',
#  'persons',
#  'conjugal',
#  'relationship',
#  'marriage',
#  'conjoint',
#  ...]

# %%
nouns_lower= list(map(lambda x: x.lower(), nouns))

# %%
nouns_unique = list(set(nouns_lower))

# %%
len(nouns_unique)
# Out:
# 1297

# %%
nouns_unique
# Out:
# ['sched',
#  'common',
#  'property',
#  'proceeding',
#  'exercise',
#  'response',
#  'standards',
#  'joint',
#  'i.',
#  'retrofit',
#  'bed',
#  'individuals',
#  'social',
#  'linen',
#  'maintaining',
#  'connection',
#  'associate',
#  'attending',
#  'ou',
#  'officer',
#  'measures',
#  'immunity',
#  'elements',
#  'non-compliance',
#  'compliance',
#  'plan',
#  'skills',
#  'privacy',
#  'dwelling',
#  'body',
#  'development',
#  'impairments',
#  'reduction',
#  'confidence',
#  'regard',
#  'relationship',
#  'confusion',
#  'text',
#  'construction',
#  'marriage',
#  'parry',
#  'shares',
#  'beginning',
#  'receiving',
#  'alterations',
#  'services',
#  'approaches',
#  'child',
#  'infirmier',
#  'providing',
#  'employment',
#  'surrender',
#  'subject',
#  'kinds',
#  'issues',
#  'deadline',
#  'terms',
#  'william',
#  'sheriff',
#  'stages',
#  'form',
#  'care',
#  'priorities',
#  'high-quality',
#  'co-ordination',
#  'safety',
#  'revision',
#  'average',
#  'extent',
#  'arrangements',
#  'reserve',
#  'conviction',
#  'set',
#  'making',
#  'hygiene',
#  'friends',
#  'well-being',
#  'constitute',
#  'references',
#  'are',
#  'i',
#  'use',
#  'auxiliaire',
#  'audit',
#  'discretion',
#  'express',
#  'prévoit',
#  'receivers',
#  'co-ordinator',
#  'investigation',
#  'decision-making',
#  'fire',
#  'reasons',
#  'transfers',
#  'table',
#  'joseph',
#  'operation',
#  'licensing',
#  'occupational',
#  'interim',
#  'implications',
#  'retirement',
#  'urgency',
#  'improvements',
#  'exception',
#  'belief',
#  'tests',
#  'facility',
#  'device',
#  'parties',
#  'certainty',
#  'affords',
#  'copy',
#  'offences',
#  'acceptance',
#  'money',
#  'precautions',
#  'independence',
#  'accounts',
#  'amendments',
#  'falls',
#  'findings',
#  'suspension',
#  'allocation',
#  'déclaration',
#  'premises',
#  'loss',
#  'fact',
#  'implementation',
#  'long-term',
#  'emo',
#  'classes',
#  'degree',
#  'miscellaneous',
#  's.',
#  'municipal',
#  'manager',
#  'veteran',
#  'business',
#  'ceasing',
#  'modernisation',
#  'iii.1',
#  'integrity',
#  'gains',
#  'employee',
#  'monitors',
#  'honest',
#  'voting',
#  'general',
#  'step',
#  'corporate',
#  'recommendations',
#  'george',
#  'delay',
#  'k',
#  'a',
#  'résident',
#  'professionals',
#  'practices',
#  'telephone',
#  'pasds',
#  'condition',
#  'governing',
#  'components',
#  'recovery',
#  'unit',
#  'clause',
#  'municipality',
#  'justice',
#  'settlement',
#  'reports',
#  'defence',
#  'extinguishment',
#  'programs',
#  'screening',
#  'confirmation',
#  'information',
#  'yorkview',
#  'institution',
#  'respect',
#  'promotion',
#  'course',
#  'rules',
#  'error',
#  'hearings',
#  'diagnosis',
#  'q',
#  'declarations',
#  'coercion',
#  'limitations',
#  'meet',
#  'delivery',
#  'contravention',
#  'decision',
#  'no',
#  'therapy',
#  'matière',
#  'document',
#  'reissue',
#  'inquest',
#  'chapter',
#  'directrices',
#  'kind',
#  'revisions',
#  'superior',
#  'act',
#  'officials',
#  'lookout',
#  'provide',
#  'institutions',
#  'boards',
#  'limits',
#  'fee',
#  'droits',
#  'changes',
#  'confinement',
#  'notice',
#  'judge',
#  'comments',
#  'security',
#  'temperature',
#  'conclusions',
#  'preference',
#  'l',
#  'advisers',
#  'protection',
#  'term',
#  'salary',
#  'decisions',
#  'result',
#  'capital',
#  'format',
#  'trail',
#  'meaning',
#  'reassessment',
#  'confidentiality',
#  'upgrade',
#  'martha',
#  'stating',
#  'assembly',
#  'period',
#  'autorisée',
#  'caregivers',
#  'disadvantages',
#  'matters',
#  'further',
#  'hospitals',
#  'resources',
#  'conjoint',
#  'principles',
#  'voiding',
#  'types',
#  'suspicion',
#  'southern',
#  'transmission',
#  'inspection',
#  'power',
#  'portions',
#  'establishment',
#  'testing',
#  'g.1',
#  'difference',
#  'rights',
#  'renovation',
#  'change',
#  'test',
#  'check',
#  'bignucolo',
#  'y',
#  'area',
#  'setting',
#  'formation',
#  'supply',
#  'community',
#  'guide',
#  'total',
#  'associates',
#  'workers',
#  'personnels',
#  'concerns',
#  'threat',
#  'insurance',
#  'word',
#  'qualifications',
#  'considerations',
#  'secure',
#  'office',
#  'needs',
#  'indicating',
#  'directors',
#  'omission',
#  'niagara',
#  'prepare',
#  'repealed',
#  'principe',
#  'obstruct',
#  'contents',
#  'operate',
#  'lack',
#  'foregoing',
#  'executive',
#  'groups',
#  'transparency',
#  'goods',
#  'coerces',
#  'week',
#  'procedures',
#  'youth',
#  'resulting',
#  'subclause',
#  'minimum',
#  'nord',
#  'hornepayne',
#  'practice',
#  'inquiries',
#  'contrary',
#  'professions',
#  'agents',
#  'emergencies',
#  'protections',
#  'aged',
#  'choices',
#  'charges',
#  'reductions',
#  'government',
#  'admissibility',
#  'quality',
#  'participante',
#  'omissions',
#  'discontinuation',
#  'p.m.',
#  'specification',
#  'anything',
#  'submit',
#  'publication',
#  'assessments',
#  'fear',
#  'regulations',
#  'combination',
#  'day',
#  'repair',
#  'physiotherapy',
#  'local',
#  'modification',
#  'times',
#  'a.m.',
#  'steps',
#  'days',
#  'remedy',
#  'perimeter',
#  'borrowings',
#  'clauses',
#  'definitions',
#  'proof',
#  'return',
#  'attention',
#  'amounts',
#  'samples',
#  'dunn',
#  'grant',
#  'sufficient',
#  'appropriate',
#  'o',
#  'regulation',
#  'purposes',
#  'misappropriation',
#  'guideline',
#  'rule',
#  'conduct',
#  'exemptions',
#  'methods',
#  'inclusion',
#  'proceedings',
#  'results',
#  'titulaire',
#  'intent',
#  'restrictive',
#  'clothing',
#  'request',
#  'statement',
#  'applications',
#  'locks',
#  'etc',
#  'support',
#  'burden',
#  'demand',
#  'material',
#  'paragraph',
#  'obligations',
#  'procedure',
#  'client',
#  'effectiveness',
#  'responsibilities',
#  'district',
#  'exclusions',
#  'i.1',
#  'orientation',
#  'proposal',
#  'francophone',
#  'durée',
#  'c',
#  'ministry',
#  'restraint',
#  'expectations',
#  'survey',
#  'attendance',
#  'onus',
#  'nurse',
#  'full-time',
#  'cost',
#  'trust',
#  'possibility',
#  'residents',
#  'divisional',
#  'directives',
#  'que',
#  'concern',
#  'suspending',
#  'apportionment',
#  'paragraphs',
#  'integration',
#  'police',
#  'manual',
#  'vii',
#  'supérieure',
#  'plans',
#  'official',
#  'omitted',
#  'name',
#  'future',
#  'misuse',
#  'source',
#  'assistants',
#  'restitution',
#  'commissioner',
#  'contracts',
#  'honesty',
#  'etobicoke',
#  'laundry',
#  'proportion',
#  'effect',
#  'percentage',
#  'convictions',
#  'requiring',
#  'estimates',
#  'assessment',
#  'partnership',
#  'discharge',
#  'documents',
#  'administrator',
#  'l.1',
#  'applies',
#  'obstructs',
#  'friendships',
#  'ii',
#  'canada',
#  'résidents',
#  'same',
#  'data',
#  'postponement',
#  'operations',
#  'restorative',
#  'traitement',
#  'lives',
#  'persons',
#  'substitute',
#  'relevant',
#  'co-operate',
#  'permission',
#  'improper',
#  'priority',
#  'arbitration',
#  'provisions',
#  'sale',
#  'ability',
#  'duration',
#  'du',
#  'province',
#  'objective',
#  'grove',
#  'interpretation',
#  'viii',
#  'affecting',
#  'director',
#  'duties',
#  's',
#  'employers',
#  'disclosure',
#  'places',
#  'firmly',
#  'infirmity',
#  'measure',
#  'palliative',
#  'surgeons',
#  'assistant',
#  'circumstances',
#  'médecin',
#  'pictures',
#  'blind',
#  'materials',
#  'commitment',
#  'signature',
#  'decides',
#  'instance',
#  'behaviour',
#  'appointment',
#  'ownership',
#  'consideration',
#  'x',
#  'communities',
#  'contractor',
#  'obligation',
#  'confirm',
#  'part',
#  'of',
#  'soins',
#  'storage',
#  'diligence',
#  'described',
#  'authorization',
#  'event',
#  'ontario',
#  'regency',
#  'ground',
#  'checks',
#  'december',
#  'r',
#  'imprisonment',
#  'written',
#  'following',
#  'provincial',
#  'appeals',
#  'criteria',
#  'title',
#  'dietary',
#  'windsor',
#  'enforcement',
#  'collaboration',
#  'decision-makers',
#  'recording',
#  'geraldton',
#  'proclamation',
#  'oath',
#  'things',
#  'veterans',
#  'consultation',
#  'd.3',
#  'currency',
#  'affirm',
#  'sud',
#  'advice',
#  'stay',
#  'approvals',
#  'courts',
#  'emergency',
#  'confining',
#  'transaction',
#  'process',
#  'directeur',
#  'infection',
#  'charging',
#  'muskoka',
#  'hearing',
#  'destruction',
#  'etc.',
#  'discrimination',
#  'position',
#  'matter',
#  'court',
#  'effort',
#  'population',
#  'acts',
#  'park',
#  'design',
#  'must',
#  'retaliation',
#  'probation',
#  'possess',
#  'friend',
#  'relationships',
#  'inspections',
#  'language',
#  'penalties',
#  'consent',
#  'practitioner',
#  'beliefs',
#  'exceptions',
#  'disagreement',
#  'proportionate',
#  'administration',
#  'liability',
#  'representations',
#  'principle',
#  'iv',
#  'violation',
#  'strongly',
#  'cancellation',
#  'minister',
#  'impairment',
#  'redevelopment',
#  'reporting',
#  'oversight',
#  'français',
#  'welfare',
#  'possession',
#  'expression',
#  'not-for-profit',
#  'chapleau',
#  'infections',
#  'ceases',
#  'correction',
#  'time',
#  'absent',
#  'inspector',
#  'room',
#  'payment',
#  'evaluates',
#  'give',
#  'extendicare',
#  'access',
#  'senior',
#  'e',
#  'subsections',
#  'freedom',
#  'b',
#  'reviews',
#  'intervals',
#  'centre',
#  'physician',
#  'closing',
#  'role',
#  'interferes',
#  'non-arm',
#  'ontarians',
#  'february',
#  'charitable',
#  'sound',
#  'r.n',
#  'd',
#  'rainy',
#  'confiner',
#  'people',
#  'behalf',
#  'comfort',
#  'vi',
#  'absence',
#  'labour',
#  'cases',
#  'treatment',
#  'responses',
#  'witness',
#  'light',
#  'person',
#  'specifies',
#  'determinations',
#  'writing',
#  'prevention',
#  'd.1',
#  'areas',
#  'continuous',
#  'regulated',
#  'hospital',
#  'communication',
#  'discipline',
#  'employeur',
#  'evacuation',
#  'volunteer',
#  'collection',
#  'therapists',
#  'disposition',
#  'head',
#  'revenue',
#  'river',
#  'expropriations',
#  'm',
#  'grants',
#  'undertaking',
#  'medical',
#  'devices',
#  'harm',
#  'orders',
#  'possessions',
#  'peace',
#  'convene',
#  'refrain',
#  'conditions',
#  'virtue',
#  'nipigon',
#  'requests',
#  'privilege',
#  'practitioners',
#  'lakeland',
#  'brother',
#  'eligibility',
#  'review',
#  'upon',
#  'nursing',
#  'minutes',
#  'prosecution',
#  'bankruptcy',
#  'filing',
#  'j',
#  'division',
#  'expense',
#  'consents',
#  'offence',
#  'clarifying',
#  'determines',
#  'quantity',
#  'employer',
#  'ineligibility',
#  'explanation',
#  'grounds',
#  'convenience',
#  'advantages',
#  'receiver',
#  'transcript',
#  'january',
#  'opinion',
#  'withdrawn',
#  'crown',
#  'repairs',
#  'list',
#  'transfer',
#  'questioning',
#  'law',
#  'value',
#  'sums',
#  'lignes',
#  'participates',
#  'basis',
#  'comply',
#  'workforce',
#  'present',
#  'sister',
#  'inability',
#  'opportunity',
#  'faith',
#  'cleanliness',
#  'notification',
#  'consult',
#  'substance',
#  'type',
#  'record',
#  'directive',
#  'a.1',
#  'lady',
#  'facilities',
#  'entities',
#  'public',
#  'selects',
#  'retaliate',
#  'magnitude',
#  'agent',
#  'individuality',
#  'coroners',
#  'intimidating',
#  's.o',
#  'physicians',
#  'continuity',
#  'd/m/y',
#  'functions',
#  'satisfies',
#  'sufficiency',
#  'expenditures',
#  'repeal',
#  'nature',
#  'partner',
#  'corporation',
#  'meeting',
#  'diversity',
#  'competence',
#  'advise',
#  'certificate',
#  'costs',
#  'amendment',
#  'questions',
#  'clerk',
#  'way',
#  'means',
#  'smooth',
#  'employees',
#  'management',
#  'commissioners',
#  'heading',
#  'manor',
#  'applicant',
#  'aspect',
#  'goals',
#  'copies',
#  'entry',
#  'towards',
#  'policy',
#  'decision-maker',
#  'addition',
#  'life',
#  'w',
#  'bar',
#  'apply',
#  'note',
#  'aspects',
#  'apportionments',
#  'direction',
#  'location',
#  'actions',
#  'occupation',
#  'code',
#  'minimizing',
#  'controls',
#  'fine',
#  'band',
#  'fluids',
#  'equity',
#  'recommendation',
#  'nurses',
#  'powers',
#  'notices',
#  'nutrition',
#  'p',
#  'board',
#  'failures',
#  'control',
#  'may',
#  'eldcap',
#  'hydration',
#  'physiotherapists',
#  'neglect',
#  'exits',
#  'officers',
#  'inspectors',
#  'interventions',
#  'issuing',
#  'pays',
#  'nothing',
#  'balance',
#  'execution',
#  'indian',
#  'manner',
#  'number',
#  'limit',
#  'foyer',
#  'content',
#  'activity',
#  'concurs',
#  'hours',
#  'utilization',
#  'prevails',
#  'subparagraph',
#  'staff',
#  'abuse',
#  'portion',
#  'vote',
#  'bayview',
#  'termination',
#  'age',
#  'lhin',
#  'jurisdiction',
#  'staffing',
#  'councils',
#  'composition',
#  'inclusions',
#  'placement',
#  'council',
#  'funding',
#  'ss',
#  'method',
#  'reprisal',
#  'complies',
#  'adviser',
#  'consequences',
#  'restraining',
#  'arises',
#  'reasonably',
#  'accommodation',
#  'township',
#  'considers',
#  'analyzes',
#  'outcome',
#  'authority',
#  'wishes',
#  'la',
#  'affidavits',
#  'receive',
#  'toronto',
#  'default',
#  'northern',
#  'standard',
#  'd.2',
#  'instructions',
#  'facts',
#  'action',
#  'performs',
#  'activities',
#  'force',
#  'borrowing',
#  'obstruction',
#  'records',
#  'inc.',
#  'assistance',
#  'g',
#  'majority',
#  'description',
#  'interest',
#  'member',
#  'commission',
#  'application',
#  'work',
#  'recognition',
#  'confidential',
#  'explain',
#  'subsection',
#  'homes',
#  'occupier',
#  'entrances',
#  'fees',
#  'amending',
#  'holder',
#  'examinations',
#  'assist',
#  'renovations',
#  'affairs',
#  'every',
#  'package',
#  'sponsor',
#  'health',
#  'lits',
#  'removal',
#  'clarification',
#  'certain',
#  'forms',
#  'pass',
#  'involvement',
#  'barriers',
#  'volunteers',
#  'territorial',
#  'promotes',
#  'municipalities',
#  'spouse',
#  'history',
#  'living',
#  'millennium',
#  'sample',
#  'compensation',
#  'maintenance',
#  'rooms',
#  'licence',
#  'registrar',
#  'providers',
#  'policies',
#  'attempt',
#  'registration',
#  'preamble',
#  'provision',
#  'infraction',
#  'tolerance',
#  'des',
#  'arrange',
#  'end',
#  'presides',
#  'a.2',
#  'transactions',
#  'generality',
#  'interference',
#  'concentration',
#  'incident',
#  'sioux',
#  'limitation',
#  'communications',
#  'service',
#  'state',
#  'breach',
#  'reference',
#  'question',
#  'father',
#  'contract',
#  'reason',
#  'long',
#  'employ',
#  'corporations',
#  'none',
#  'agrees',
#  'clarity',
#  'private',
#  'mechanisms',
#  'website',
#  'atikokan',
#  'wawa',
#  'cts',
#  'case',
#  'amount',
#  'posting',
#  'receipt',
#  'finance',
#  'capacity',
#  'wing',
#  'determination',
#  'restriction',
#  'judicial',
#  'operating',
#  'processing',
#  ...]

# %%
nouns_unique.sort()

# %%
nouns_unique
# Out:
# ['39',
#  'a',
#  'a.1',
#  'a.2',
#  'a.m.',
#  'ability',
#  'absence',
#  'absent',
#  'abuse',
#  'acceptance',
#  'access',
#  'accommodation',
#  'accordance',
#  'account',
#  'accountability',
#  'accounts',
#  'acknowledgement',
#  'act',
#  'action',
#  'actions',
#  'activities',
#  'activity',
#  'acts',
#  'addition',
#  'additions',
#  'address',
#  'administrateur',
#  'administration',
#  'administrator',
#  'admissibility',
#  'admission',
#  'admissions',
#  'advantages',
#  'advice',
#  'advise',
#  'adviser',
#  'advisers',
#  'affairs',
#  'affecting',
#  'affidavits',
#  'affirm',
#  'affords',
#  'age',
#  'aged',
#  'agency',
#  'agent',
#  'agents',
#  'agreement',
#  'agreements',
#  'agrees',
#  'al',
#  'allocation',
#  'alterations',
#  'alternatives',
#  'amending',
#  'amendment',
#  'amendments',
#  'amongst',
#  'amount',
#  'amounts',
#  'analyzes',
#  'and',
#  'any',
#  'anyone',
#  'anything',
#  'appeal',
#  'appeals',
#  'applicability',
#  'applicant',
#  'application',
#  'applications',
#  'applies',
#  'apply',
#  'appointment',
#  'apportion',
#  'apportionment',
#  'apportionments',
#  'approaches',
#  'appropriate',
#  'approval',
#  'approvals',
#  'arbitration',
#  'are',
#  'area',
#  'areas',
#  'argument',
#  'arises',
#  'arrange',
#  'arrangements',
#  'aspect',
#  'aspects',
#  'assembly',
#  'assessment',
#  'assessments',
#  'assist',
#  'assistance',
#  'assistant',
#  'assistants',
#  'associate',
#  'associates',
#  'atikokan',
#  'attachment',
#  'attempt',
#  'attempts',
#  'attendance',
#  'attending',
#  'attention',
#  'audit',
#  'authority',
#  'authorization',
#  'authorizations',
#  'autorisé',
#  'autorisée',
#  'auxiliaire',
#  'availability',
#  'average',
#  'b',
#  'b.1',
#  'balance',
#  'band',
#  'bands',
#  'bankruptcy',
#  'bar',
#  'barriers',
#  'basis',
#  'bayview',
#  'bed',
#  'beds',
#  'beginning',
#  'behalf',
#  'behaviour',
#  'belief',
#  'beliefs',
#  'benefit',
#  'bignucolo',
#  'bill',
#  'billings',
#  'blind',
#  'board',
#  'boards',
#  'body',
#  'borrowing',
#  'borrowings',
#  'breach',
#  'brother',
#  'burden',
#  'burlington',
#  'business',
#  'by-law',
#  'bénévole',
#  'c',
#  'calculation',
#  'canada',
#  'cancellation',
#  'capacity',
#  'capital',
#  'care',
#  'caregiver',
#  'caregivers',
#  'case',
#  'cases',
#  'category',
#  'catégorie',
#  'cause',
#  'ceases',
#  'ceasing',
#  'cent',
#  'centre',
#  'certain',
#  'certainty',
#  'certificate',
#  'cessation',
#  'change',
#  'changes',
#  'chapleau',
#  'chapter',
#  'charge',
#  'charges',
#  'charging',
#  'charitable',
#  'check',
#  'checks',
#  'child',
#  'choice',
#  'choices',
#  'circumstances',
#  'citizen',
#  'clarification',
#  'clarifying',
#  'clarity',
#  'class',
#  'classes',
#  'classification',
#  'clause',
#  'clauses',
#  'cleanliness',
#  'clerk',
#  'client',
#  'closing',
#  'clothing',
#  'co-operate',
#  'co-ordination',
#  'co-ordinator',
#  'co-ordinators',
#  'code',
#  'coerces',
#  'coercion',
#  'collaborate',
#  'collaboration',
#  'collection',
#  'college',
#  'combination',
#  'comfort',
#  'comments',
#  'commission',
#  'commissioner',
#  'commissioners',
#  'commitment',
#  'committee',
#  'common',
#  'commun',
#  'communication',
#  'communications',
#  'communities',
#  'community',
#  'compensation',
#  'competence',
#  'competitive',
#  'complaint',
#  'complaints',
#  'compliance',
#  'complies',
#  'comply',
#  'components',
#  'composition',
#  'concentration',
#  'concern',
#  'concerns',
#  'conclusions',
#  'concurs',
#  'condition',
#  'conditions',
#  'conduct',
#  'confidence',
#  'confidential',
#  'confidentiality',
#  'confine',
#  'confinement',
#  'confiner',
#  'confining',
#  'confirm',
#  'confirmation',
#  'conflict',
#  'confusion',
#  'conjoint',
#  'conjugal',
#  'connection',
#  'conseiller',
#  'consent',
#  'consents',
#  'consequences',
#  'consideration',
#  'considerations',
#  'considers',
#  'consistency',
#  'consolidation',
#  'constitute',
#  'constitutes',
#  'construction',
#  'consult',
#  'consultation',
#  'contact',
#  'content',
#  'contents',
#  'continuation',
#  'continuity',
#  'continuous',
#  'contract',
#  'contractor',
#  'contractors',
#  'contracts',
#  'contrary',
#  'contravention',
#  'control',
#  'controls',
#  'convene',
#  'convenience',
#  'conviction',
#  'convictions',
#  'copies',
#  'copy',
#  'copying',
#  'coroners',
#  'corporate',
#  'corporation',
#  'corporations',
#  'correction',
#  'cost',
#  'costs',
#  'council',
#  'councils',
#  'counsel',
#  'course',
#  'court',
#  'courtesy',
#  'courts',
#  'criteria',
#  'crown',
#  'cts',
#  'currency',
#  'custody',
#  'd',
#  "d'appel",
#  "d'intégration",
#  'd.1',
#  'd.2',
#  'd.3',
#  'd/m/y',
#  'damages',
#  'data',
#  'date',
#  'day',
#  'days',
#  'deadline',
#  'deals',
#  'dealt',
#  'debt',
#  'december',
#  'decides',
#  'decision',
#  'decision-maker',
#  'decision-makers',
#  'decision-making',
#  'decisions',
#  'declarations',
#  'default',
#  'defence',
#  'definition',
#  'definitions',
#  'degree',
#  'degrees',
#  'delay',
#  'delivery',
#  'demand',
#  'dementia',
#  'des',
#  'described',
#  'description',
#  'design',
#  'designation',
#  'designations',
#  'destruction',
#  'determination',
#  'determinations',
#  'determines',
#  'development',
#  'device',
#  'devices',
#  'diagnosis',
#  'dietary',
#  'difference',
#  'dignity',
#  'diligence',
#  'directeur',
#  'direction',
#  'directions',
#  'directive',
#  'directives',
#  'director',
#  'directors',
#  'directrices',
#  'directs',
#  'disability',
#  'disadvantages',
#  'disagreement',
#  'discharge',
#  'discipline',
#  'disclosure',
#  'discontinuation',
#  'discretion',
#  'discrimination',
#  'disposition',
#  'disputes',
#  'distribution',
#  'district',
#  'diversity',
#  'division',
#  'divisional',
#  'document',
#  'documentation',
#  'documents',
#  'droits',
#  'drug',
#  'drugless',
#  'drugs',
#  'du',
#  'dunn',
#  'duration',
#  'durée',
#  'duties',
#  'duty',
#  'dwelling',
#  'dwellings',
#  'déclaration',
#  'e',
#  'effect',
#  'effectiveness',
#  'effort',
#  'eldcap',
#  'elements',
#  'eligibility',
#  'elm',
#  'emergencies',
#  'emergency',
#  'emo',
#  'employ',
#  'employee',
#  'employees',
#  'employer',
#  'employers',
#  'employeur',
#  'employment',
#  'enactment',
#  'encourages',
#  'end',
#  'enforcement',
#  'enters',
#  'entities',
#  'entitlements',
#  'entity',
#  'entrances',
#  'entry',
#  'environment',
#  'equipment',
#  'equity',
#  'error',
#  'errors',
#  'espanola',
#  'establishment',
#  'estimates',
#  'etc',
#  'etc.',
#  'etobicoke',
#  'evacuation',
#  'evaluates',
#  'event',
#  'every',
#  'everything',
#  'evidence',
#  'examination',
#  'examinations',
#  'exception',
#  'exceptions',
#  'exclusions',
#  'execution',
#  'executive',
#  'exemptions',
#  'exercise',
#  'exigence',
#  'exits',
#  'expectations',
#  'expenditures',
#  'expense',
#  'expertise',
#  'experts',
#  'expiry',
#  'explain',
#  'explanation',
#  'express',
#  'expression',
#  'expropriations',
#  'extended',
#  'extendicare',
#  'extension',
#  'extent',
#  'extinguishment',
#  'f',
#  'f.1',
#  'facilities',
#  'facility',
#  'fact',
#  'factors',
#  'facts',
#  'failure',
#  'failures',
#  'faith',
#  'falls',
#  'families',
#  'family',
#  'father',
#  'fear',
#  'february',
#  'fee',
#  'fees',
#  'file',
#  'filing',
#  'film',
#  'finance',
#  'findings',
#  'fine',
#  'fire',
#  'firmly',
#  'first',
#  'fluids',
#  'following',
#  'food',
#  'force',
#  'foregoing',
#  'form',
#  'format',
#  'formation',
#  'forms',
#  'foyer',
#  'francophone',
#  'français',
#  'fraud',
#  'freedom',
#  'friend',
#  'friends',
#  'friendships',
#  'full-time',
#  'functions',
#  'fundamental',
#  'funding',
#  'funds',
#  'furnishings',
#  'further',
#  'future',
#  'g',
#  'g.1',
#  'gains',
#  'general',
#  'generality',
#  'george',
#  'geraldton',
#  'give',
#  'goal',
#  'goals',
#  'goods',
#  'governing',
#  'government',
#  'governments',
#  'governor',
#  'grant',
#  'grants',
#  'ground',
#  'grounds',
#  'groups',
#  'grove',
#  'guelph',
#  'guide',
#  'guideline',
#  'guidelines',
#  'h',
#  'hamilton',
#  'harm',
#  'head',
#  'heading',
#  'health',
#  'hearing',
#  'hearings',
#  'her',
#  'high-quality',
#  'hinder',
#  'hinders',
#  'history',
#  'holder',
#  'home',
#  'homes',
#  'honest',
#  'honesty',
#  'hornepayne',
#  'hospital',
#  'hospitalization',
#  'hospitals',
#  'hours',
#  'house',
#  'hydration',
#  'hygiene',
#  'i',
#  'i.',
#  'i.1',
#  'ii',
#  'iii',
#  'iii.1',
#  'immunity',
#  'impairment',
#  'impairments',
#  'implementation',
#  'implications',
#  'importance',
#  'imprisonment',
#  'improper',
#  'improvement',
#  'improvements',
#  'inability',
#  'inc.',
#  'incident',
#  'inclusion',
#  'inclusions',
#  'incorporation',
#  'increase',
#  'independence',
#  'indian',
#  'indicating',
#  'individual',
#  'individuality',
#  'individuals',
#  'ineligibility',
#  'infection',
#  'infections',
#  'infirmier',
#  'infirmiers',
#  'infirmity',
#  'information',
#  'infraction',
#  'inquest',
#  'inquiries',
#  'inquiry',
#  'inspection',
#  'inspections',
#  'inspector',
#  'inspectors',
#  'instance',
#  'institution',
#  'institutions',
#  'instructions',
#  'insurance',
#  'integration',
#  'integrity',
#  'intent',
#  'intention',
#  'interest',
#  'interests',
#  'interference',
#  'interferes',
#  'interim',
#  'interpretation',
#  'intervals',
#  'intervention',
#  'interventions',
#  'intimidating',
#  'investigation',
#  'involvement',
#  'issuance',
#  'issue',
#  'issues',
#  'issuing',
#  'iv',
#  'ix',
#  'j',
#  'january',
#  'joint',
#  'joseph',
#  'judge',
#  'judicial',
#  'jurisdiction',
#  'justice',
#  'k',
#  'kind',
#  'kinds',
#  'knowledge',
#  'l',
#  'l.1',
#  'la',
#  'labour',
#  'lack',
#  'lady',
#  'lakeland',
#  'language',
#  'laundry',
#  'law',
#  'lawyer',
#  'legislation',
#  'legislative',
#  'length',
#  'lhin',
#  'liability',
#  'licence',
#  'licences',
#  'licensee',
#  'licensees',
#  'licensing',
#  'lieutenant',
#  'life',
#  'lifecare',
#  'light',
#  'lignes',
#  'limit',
#  'limitation',
#  'limitations',
#  'limits',
#  'linen',
#  'list',
#  'lits',
#  'lives',
#  'living',
#  'local',
#  'location',
#  'locks',
#  'long',
#  'long-term',
#  'lookout',
#  'loss',
#  'm',
#  'magnitude',
#  'maintaining',
#  'maintenance',
#  'majesty',
#  'majority',
#  'making',
#  'manage',
#  'management',
#  'manager',
#  'manitouwadge',
#  'manner',
#  'manor',
#  'manual',
#  'marriage',
#  'martha',
#  'material',
#  'materials',
#  'matheson',
#  'matière',
#  'matter',
#  'matters',
#  'may',
#  'meaning',
#  'means',
#  'measure',
#  'measures',
#  'mechanisms',
#  'medical',
#  'medicare',
#  'meet',
#  'meeting',
#  'meetings',
#  'member',
#  'members',
#  'memorial',
#  'method',
#  'methods',
#  'millennium',
#  'minimizing',
#  'minimum',
#  'minister',
#  'ministry',
#  'ministère',
#  'minutes',
#  'misappropriation',
#  'miscellaneous',
#  'misrepresentation',
#  'mission',
#  'misuse',
#  'modernisation',
#  'modification',
#  'modifications',
#  'money',
#  'monitors',
#  'months',
#  'mother',
#  'movement',
#  'municipal',
#  'municipalities',
#  'municipality',
#  'municipalité',
#  'muskoka',
#  'must',
#  'médecin',
#  'n',
#  'name',
#  'nations',
#  'nature',
#  'need',
#  'needs',
#  'neglect',
#  'network',
#  'niagara',
#  'nipigon',
#  'no',
#  'non-application',
#  'non-arm',
#  'non-compliance',
#  'non-continuation',
#  'none',
#  'nord',
#  'northern',
#  'not-for-profit',
#  'note',
#  'nothing',
#  'notice',
#  'notices',
#  'notification',
#  'november',
#  'number',
#  'numbers',
#  'nurse',
#  'nurses',
#  'nursing',
#  'nursing/retirement',
#  'nutrition',
#  'o',
#  'oath',
#  'objective',
#  'obligation',
#  'obligations',
#  'obstruct',
#  'obstruction',
#  'obstructs',
#  'occupancy',
#  'occupation',
#  'occupational',
#  'occupier',
#  'occupies',
#  'of',
#  'offence',
#  'offences',
#  'office',
#  'officer',
#  'officers',
#  'official',
#  'officials',
#  'omission',
#  'omissions',
#  'omitted',
#  'ontarians',
#  'ontario',
#  'onus',
#  'operate',
#  'operating',
#  'operation',
#  'operations',
#  'opinion',
#  'opportunity',
#  'option',
#  'order',
#  'orders',
#  'organizations',
#  'orientation',
#  'others',
#  'ou',
#  'outcome',
#  'outcomes',
#  'overbeds',
#  'oversight',
#  'ownership',
#  'p',
#  'p.m.',
#  'package',
#  'palliative',
#  'paragraph',
#  'paragraphs',
#  'park',
#  'parry',
#  'part',
#  'participante',
#  'participates',
#  'participation',
#  'parties',
#  'partner',
#  'partnership',
#  'parts',
#  'party',
#  'pasd',
#  'pasds',
#  'pass',
#  'pay',
#  'payment',
#  'payments',
#  'pays',
#  'peace',
#  'pelee',
#  'penalties',
#  'penalty',
#  'people',
#  'percentage',
#  'performance',
#  'performs',
#  'perimeter',
#  'period',
#  'periods',
#  'permission',
#  'person',
#  'personal',
#  'personnel',
#  'personnels',
#  'persons',
#  'philosophy',
#  'physician',
#  'physicians',
#  'physiotherapists',
#  'physiotherapy',
#  'pictures',
#  'place',
#  'placement',
#  'places',
#  'plan',
#  'plans',
#  'police',
#  'policies',
#  'policy',
#  'population',
#  'portion',
#  'portions',
#  'position',
#  'possess',
#  'possession',
#  'possessions',
#  'possibility',
#  'posting',
#  'postponement',
#  'power',
#  'powers',
#  'practice',
#  'practices',
#  'practitioner',
#  'practitioners',
#  'preamble',
#  'precautions',
#  'preference',
#  'preferences',
#  'premises',
#  'prepare',
#  'presence',
#  'present',
#  'preside',
#  'presides',
#  'prevails',
#  'prevention',
#  'principe',
#  'principle',
#  'principles',
#  'priorities',
#  'priority',
#  'privacy',
#  'private',
#  'privilege',
#  'probation',
#  'procedure',
#  'procedures',
#  'proceeding',
#  'proceedings',
#  'process',
#  'processing',
#  'proclamation',
#  'production',
#  'professionals',
#  'professions',
#  'program',
#  'programs',
#  'promotes',
#  'promotion',
#  'proof',
#  'property',
#  'proportion',
#  'proportionate',
#  'proposal',
#  'prosecution',
#  'protection',
#  'protections',
#  'provide',
#  'providers',
#  'providing',
#  'province',
#  'provincial',
#  'provision',
#  'provisions',
#  'prévoit',
#  'psychotropic',
#  'public',
#  'publication',
#  'purpose',
#  'purposes',
#  'pursuant',
#  'q',
#  'qualifications',
#  'quality',
#  'quantity',
#  'que',
#  'question',
#  'questioning',
#  'questions',
#  'r',
#  'r.n',
#  'rainy',
#  'reason',
#  'reasonably',
#  'reasons',
#  'reassessment',
#  'reassessments',
#  'receipt',
#  'receive',
#  'receiver',
#  'receivers',
#  'receiving',
#  'recognition',
#  'recommendation',
#  'recommendations',
#  'record',
#  'recording',
#  ...]

# %%
test='RESIDENTS'
test.lower()
# Out:
# 'residents'

# %%
help(test.lower)
# Out:
# Help on built-in function lower:
#
# lower() method of builtins.str instance
#     Return a copy of the string converted to lowercase.
